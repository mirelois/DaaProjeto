# %% [markdown]
# # Tarefa Competição

# %%
import sklearn as skl
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
import numpy as np
from datetime import datetime
import pickle as pkl

# %%
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, StratifiedShuffleSplit
from sklearn import tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier, VotingClassifier, BaggingClassifier, StackingClassifier
import xgboost as xgb
from xgboost.sklearn import XGBClassifier
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV, KFold

# %%
def SaveModel(name, model_name):
    with open(name, "wb") as fd:
        pkl.dump(model_name, fd)

def UseModel(name):
    with open(name, "rb") as fd:
        return pkl.load(fd)

# %%
def kaggleMaker(df,model,num):
    kaggle_model = model.predict(df)

    # Supondo que kaggle_model seja uma matriz NumPy ou uma série Pandas unidimensional
    kaggle_model = kaggle_model.reshape(-1, 1)  # Reshape para torná-lo bidimensional

    # Criar DataFrame com uma única coluna
    prediction = pd.DataFrame(kaggle_model, columns=["Result"])

    # Adicionar uma coluna "RowId" com índices crescentes
    prediction["RowId"] = range(1, len(prediction) + 1)

    # Reorganizar as colunas
    prediction = prediction[["RowId", "Result"]]

    categoria_para_numero = {0:'None' ,  1:'Low', 2:'Medium',  3:'High', 4:'Very High' }
    prediction['Result'] = prediction['Result'].map(categoria_para_numero)

    # Salvar o DataFrame em um arquivo CSV
    prediction.to_csv(f"Pred{num}.csv", index=False)

# %%
resultados = {}

# %%
df0 = pd.read_csv("meteo_202109-202112.csv", na_filter = True)
df1 = pd.read_csv("meteo_202201-202212.csv", na_filter = True)

df_teste0 =  pd.read_csv ("meteo_202301-202304.csv", na_filter = True)

# %% [markdown]
# # Nova secção

# %%
df_meteo = pd.concat([df0, df1], ignore_index=True)

# %%
df_meteo.head()
# Out:
#            dt                         dt_iso city_name   temp  feels_like  \
# 0  1630454400  2021-09-01 00:00:00 +0000 UTC     local  18.74       18.84
# 1  1630458000  2021-09-01 01:00:00 +0000 UTC     local  18.73       18.83
# 2  1630461600  2021-09-01 02:00:00 +0000 UTC     local  17.84       17.98
# 3  1630465200  2021-09-01 03:00:00 +0000 UTC     local  18.27       18.40
# 4  1630468800  2021-09-01 04:00:00 +0000 UTC     local  17.81       17.97
#
#    temp_min  temp_max  pressure  sea_level  grnd_level  humidity  wind_speed  \
# 0     15.72     20.34      1015        NaN         NaN        83        1.18
# 1     15.72     20.34      1014        NaN         NaN        83        1.46
# 2     16.72     20.34      1014        NaN         NaN        88        1.05
# 3     16.68     20.34      1014        NaN         NaN        86        0.46
# 4     16.12     20.34      1013        NaN         NaN        89        0.93
#
#    rain_1h  clouds_all weather_description
# 0      NaN          78       broken clouds
# 1      NaN          92     overcast clouds
# 2      NaN          91     overcast clouds
# 3     0.14          94          light rain
# 4     1.26          95       moderate rain

# %%
df_meteo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11688 entries, 0 to 11687
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dt                   11688 non-null  int64
#  1   dt_iso               11688 non-null  object
#  2   city_name            11688 non-null  object
#  3   temp                 11688 non-null  float64
#  4   feels_like           11688 non-null  float64
#  5   temp_min             11688 non-null  float64
#  6   temp_max             11688 non-null  float64
#  7   pressure             11688 non-null  int64
#  8   sea_level            0 non-null      float64
#  9   grnd_level           0 non-null      float64
#  10  humidity             11688 non-null  int64
#  11  wind_speed           11688 non-null  float64
#  12  rain_1h              2435 non-null   float64
#  13  clouds_all           11688 non-null  int64
#  14  weather_description  11688 non-null  object
# dtypes: float64(8), int64(4), object(3)
# memory usage: 1.3+ MB

# %%
df_meteo.describe()
# Out:
#                  dt          temp    feels_like      temp_min      temp_max  \
# count  1.168800e+04  11688.000000  11688.000000  11688.000000  11688.000000
# mean   1.651491e+09     16.406638     16.076164     14.433353     17.502990
# std    1.214705e+07      5.715977      6.217605      4.960590      6.112344
# min    1.630454e+09      0.320000     -2.190000     -0.640000      1.330000
# 25%    1.640973e+09     12.350000     11.760000     10.900000     12.930000
# 50%    1.651491e+09     15.760000     15.675000     14.540000     16.720000
# 75%    1.662009e+09     19.540000     19.560000     17.720000     20.700000
# max    1.672528e+09     40.850000     41.330000     36.720000     41.450000
#
#            pressure  sea_level  grnd_level      humidity    wind_speed  \
# count  11688.000000        0.0         0.0  11688.000000  11688.000000
# mean    1018.304073        NaN         NaN     76.619011      2.647688
# std        6.109727        NaN         NaN     16.157421      1.458574
# min      994.000000        NaN         NaN     19.000000      0.060000
# 25%     1015.000000        NaN         NaN     66.000000      1.610000
# 50%     1018.000000        NaN         NaN     81.000000      2.380000
# 75%     1022.000000        NaN         NaN     91.000000      3.400000
# max     1034.000000        NaN         NaN    100.000000     11.100000
#
#            rain_1h    clouds_all
# count  2435.000000  11688.000000
# mean      0.884760     54.258214
# std       1.073453     40.443374
# min       0.100000      0.000000
# 25%       0.210000      7.000000
# 50%       0.450000     60.000000
# 75%       1.070000     98.000000
# max       7.450000    100.000000

# %%
df_meteo.nunique()
# Out:
# dt                     11688
# dt_iso                 11688
# city_name                  1
# temp                    2423
# feels_like              2702
# temp_min                 488
# temp_max                 550
# pressure                  41
# sea_level                  0
# grnd_level                 0
# humidity                  82
# wind_speed               771
# rain_1h                  371
# clouds_all               101
# weather_description        8
# dtype: int64

# %%
df_teste1 = pd.read_csv("energia_202301-202304.csv", na_filter = False)
df3 = pd.read_csv("energia_202109-202112.csv", na_filter = False)
df4 = pd.read_csv("energia_202201-202212.csv", na_filter = False) # na_filter falso para evitar conversão de None para NaN

# %%
df_energia = pd.concat([df3, df4], ignore_index=True)

# %%
df_energia.head()
# Out:
#          Data  Hora  Normal (kWh)  Horario Economico (kWh)  Autoconsumo (kWh)  \
# 0  2021-09-29     0           0.0                      0.0                0.0
# 1  2021-09-29     1           0.0                      0.0                0.0
# 2  2021-09-29     2           0.0                      0.0                0.0
# 3  2021-09-29     3           0.0                      0.0                0.0
# 4  2021-09-29     4           0.0                      0.0                0.0
#
#   Injecao na rede (kWh)
# 0                  None
# 1                  None
# 2                  None
# 3                  None
# 4                  None

# %%
df_energia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11016 entries, 0 to 11015
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Data                     11016 non-null  object
#  1   Hora                     11016 non-null  int64
#  2   Normal (kWh)             11016 non-null  float64
#  3   Horario Economico (kWh)  11016 non-null  float64
#  4   Autoconsumo (kWh)        11016 non-null  float64
#  5   Injecao na rede (kWh)    11016 non-null  object
# dtypes: float64(3), int64(1), object(2)
# memory usage: 516.5+ KB

# %%
df_energia.describe()
# Out:
#                Hora  Normal (kWh)  Horario Economico (kWh)  Autoconsumo (kWh)
# count  11016.000000  11016.000000             11016.000000       11016.000000
# mean      11.500000      0.202278                 0.159714           0.117314
# std        6.922501      0.349478                 0.271792           0.176762
# min        0.000000      0.000000                 0.000000           0.000000
# 25%        5.750000      0.000000                 0.000000           0.000000
# 50%       11.500000      0.000000                 0.000000           0.000000
# 75%       17.250000      0.314000                 0.288000           0.227000
# max       23.000000      3.251000                 6.978000           1.192000

# %%
df_energia.nunique()
# Out:
# Data                        459
# Hora                         24
# Normal (kWh)               1282
# Horario Economico (kWh)     851
# Autoconsumo (kWh)           752
# Injecao na rede (kWh)         5
# dtype: int64

# %% [markdown]
# ### Juntar os dois Datasets de treino

# %%
df_meteo_temp = df_meteo.copy()
df_meteo_temp['dt_iso'] = list ( map(lambda x:( datetime.strptime(x, "%Y-%m-%d %H:%M:%S %z %Z") ).strftime("%Y-%m-%d %H:%M:%S"), df_meteo['dt_iso']) )
df_meteo_temp["dt_iso"] = pd.to_datetime(df_meteo_temp["dt_iso"])
df_meteo_temp
# Out:
#                dt              dt_iso city_name   temp  feels_like  temp_min  \
# 0      1630454400 2021-09-01 00:00:00     local  18.74       18.84     15.72
# 1      1630458000 2021-09-01 01:00:00     local  18.73       18.83     15.72
# 2      1630461600 2021-09-01 02:00:00     local  17.84       17.98     16.72
# 3      1630465200 2021-09-01 03:00:00     local  18.27       18.40     16.68
# 4      1630468800 2021-09-01 04:00:00     local  17.81       17.97     16.12
# ...           ...                 ...       ...    ...         ...       ...
# 11683  1672513200 2022-12-31 19:00:00     local  15.70       15.57     15.57
# 11684  1672516800 2022-12-31 20:00:00     local  15.55       15.43     12.72
# 11685  1672520400 2022-12-31 21:00:00     local  13.45       13.28     12.23
# 11686  1672524000 2022-12-31 22:00:00     local  12.93       12.73     12.23
# 11687  1672527600 2022-12-31 23:00:00     local  12.93       12.76     12.23
#
#        temp_max  pressure  sea_level  grnd_level  humidity  wind_speed  \
# 0         20.34      1015        NaN         NaN        83        1.18
# 1         20.34      1014        NaN         NaN        83        1.46
# 2         20.34      1014        NaN         NaN        88        1.05
# 3         20.34      1014        NaN         NaN        86        0.46
# 4         20.34      1013        NaN         NaN        89        0.93
# ...         ...       ...        ...         ...       ...         ...
# 11683     15.72      1018        NaN         NaN        86        5.56
# 11684     15.70      1018        NaN         NaN        87        4.47
# 11685     13.99      1019        NaN         NaN        93        3.29
# 11686     13.43      1019        NaN         NaN        94        1.49
# 11687     13.43      1019        NaN         NaN        95        1.93
#
#        rain_1h  clouds_all   weather_description
# 0          NaN          78         broken clouds
# 1          NaN          92       overcast clouds
# 2          NaN          91       overcast clouds
# 3         0.14          94            light rain
# 4         1.26          95         moderate rain
# ...        ...         ...                   ...
# 11683     3.58         100         moderate rain
# 11684     4.20         100  heavy intensity rain
# 11685     4.23         100  heavy intensity rain
# 11686     3.90         100         moderate rain
# 11687     4.07         100  heavy intensity rain
#
# [11688 rows x 15 columns]

# %%
df_teste0_temp = df_teste0.copy()
df_teste0_temp['dt_iso'] = list ( map(lambda x:( datetime.strptime(x, "%Y-%m-%d %H:%M:%S %z %Z") ).strftime("%Y-%m-%d %H:%M:%S"), df_teste0_temp['dt_iso']) )
df_teste0_temp["dt_iso"] = pd.to_datetime(df_teste0_temp["dt_iso"])
df_teste0_temp
# Out:
#               dt              dt_iso city_name   temp  feels_like  temp_min  \
# 0     1672531200 2023-01-01 00:00:00     local  12.93       12.76     12.72
# 1     1672534800 2023-01-01 01:00:00     local  13.49       13.38     13.43
# 2     1672538400 2023-01-01 02:00:00     local  13.55       13.44     13.48
# 3     1672542000 2023-01-01 03:00:00     local  13.61       13.51     12.01
# 4     1672545600 2023-01-01 04:00:00     local  13.59       13.49     12.01
# ...          ...                 ...       ...    ...         ...       ...
# 1747  1678820400 2023-03-14 19:00:00     local  13.10       12.27     12.72
# 1748  1678824000 2023-03-14 20:00:00     local  12.30       11.83     10.72
# 1749  1678827600 2023-03-14 21:00:00     local  11.77       11.30     10.26
# 1750  1678831200 2023-03-14 22:00:00     local  10.68       10.13      9.15
# 1751  1678834800 2023-03-14 23:00:00     local  10.65       10.15      8.60
#
#       temp_max  pressure  sea_level  grnd_level  humidity  wind_speed  \
# 0        13.43      1019        NaN         NaN        95        2.02
# 1        13.90      1018        NaN         NaN        95        2.18
# 2        14.82      1017        NaN         NaN        95        2.88
# 3        14.82      1016        NaN         NaN        95        3.63
# 4        14.82      1015        NaN         NaN        95        4.58
# ...        ...       ...        ...         ...       ...         ...
# 1747     13.60      1024        NaN         NaN        69        1.87
# 1748     12.88      1023        NaN         NaN        86        1.03
# 1749     12.88      1023        NaN         NaN        88        1.03
# 1750     12.32      1023        NaN         NaN        89        1.03
# 1751     11.77      1022        NaN         NaN        91        1.19
#
#       rain_1h  clouds_all weather_description
# 0        3.72         100       moderate rain
# 1        3.26         100       moderate rain
# 2        2.44         100       moderate rain
# 3        1.74         100       moderate rain
# 4        1.13         100       moderate rain
# ...       ...         ...                 ...
# 1747      NaN          96     overcast clouds
# 1748      NaN          84       broken clouds
# 1749      NaN          84       broken clouds
# 1750      NaN          84       broken clouds
# 1751      NaN           5        sky is clear
#
# [1752 rows x 15 columns]

# %%
df_final_v0 = pd.merge(df_energia, df_meteo_temp, left_on=['Data', 'Hora'], right_on=[df_meteo_temp['dt_iso'].dt.strftime('%Y-%m-%d'),df_meteo_temp['dt_iso'].dt.hour], how='outer')
df_final_v0
# Out:
#              Data  Hora  Normal (kWh)  Horario Economico (kWh)  \
# 0      2021-09-29     0           0.0                      0.0
# 1      2021-09-29     1           0.0                      0.0
# 2      2021-09-29     2           0.0                      0.0
# 3      2021-09-29     3           0.0                      0.0
# 4      2021-09-29     4           0.0                      0.0
# ...           ...   ...           ...                      ...
# 11683  2021-09-28    19           NaN                      NaN
# 11684  2021-09-28    20           NaN                      NaN
# 11685  2021-09-28    21           NaN                      NaN
# 11686  2021-09-28    22           NaN                      NaN
# 11687  2021-09-28    23           NaN                      NaN
#
#        Autoconsumo (kWh) Injecao na rede (kWh)          dt  \
# 0                    0.0                  None  1632873600
# 1                    0.0                  None  1632877200
# 2                    0.0                  None  1632880800
# 3                    0.0                  None  1632884400
# 4                    0.0                  None  1632888000
# ...                  ...                   ...         ...
# 11683                NaN                   NaN  1632855600
# 11684                NaN                   NaN  1632859200
# 11685                NaN                   NaN  1632862800
# 11686                NaN                   NaN  1632866400
# 11687                NaN                   NaN  1632870000
#
#                    dt_iso city_name   temp  ...  temp_min  temp_max  pressure  \
# 0     2021-09-29 00:00:00     local  13.97  ...     11.45     14.04      1027
# 1     2021-09-29 01:00:00     local  13.48  ...     13.43     13.90      1028
# 2     2021-09-29 02:00:00     local  12.93  ...     12.72     13.43      1027
# 3     2021-09-29 03:00:00     local  12.61  ...     10.34     12.93      1027
# 4     2021-09-29 04:00:00     local  12.61  ...      9.79     12.93      1027
# ...                   ...       ...    ...  ...       ...       ...       ...
# 11683 2021-09-28 19:00:00     local  16.77  ...     15.72     17.32      1026
# 11684 2021-09-28 20:00:00     local  15.67  ...     14.72     16.21      1027
# 11685 2021-09-28 21:00:00     local  15.67  ...     14.72     15.70      1027
# 11686 2021-09-28 22:00:00     local  14.52  ...     12.72     15.11      1027
# 11687 2021-09-28 23:00:00     local  14.00  ...     12.57     14.55      1027
#
#        sea_level  grnd_level  humidity  wind_speed  rain_1h  clouds_all  \
# 0            NaN         NaN        81        1.96      NaN          87
# 1            NaN         NaN        82        1.83      NaN          91
# 2            NaN         NaN        84        1.96      NaN          93
# 3            NaN         NaN        85        1.85      NaN          95
# 4            NaN         NaN        86        1.83      NaN          93
# ...          ...         ...       ...         ...      ...         ...
# 11683        NaN         NaN        70        3.11      NaN          55
# 11684        NaN         NaN        72        2.97      NaN          70
# 11685        NaN         NaN        72        2.40      NaN          59
# 11686        NaN         NaN        77        2.11      NaN          37
# 11687        NaN         NaN        79        2.14      NaN          79
#
#        weather_description
# 0          overcast clouds
# 1          overcast clouds
# 2          overcast clouds
# 3          overcast clouds
# 4          overcast clouds
# ...                    ...
# 11683        broken clouds
# 11684        broken clouds
# 11685        broken clouds
# 11686     scattered clouds
# 11687        broken clouds
#
# [11688 rows x 21 columns]

# %%
df_teste_v0 = pd.merge(df_teste1, df_teste0_temp, left_on=['Data', 'Hora'], right_on=[df_teste0_temp['dt_iso'].dt.strftime('%Y-%m-%d'),df_teste0_temp['dt_iso'].dt.hour], how='outer')
df_teste_v0
# Out:
#             Data  Hora  Normal (kWh)  Horario Economico (kWh)  \
# 0     2023-01-01     0         0.000                    0.467
# 1     2023-01-01     1         0.000                    0.577
# 2     2023-01-01     2         0.000                    0.346
# 3     2023-01-01     3         0.000                    0.270
# 4     2023-01-01     4         0.000                    0.252
# ...          ...   ...           ...                      ...
# 2251  2023-04-04    19         0.953                    0.000
# 2252  2023-04-04    20         0.915                    0.000
# 2253  2023-04-04    21         0.479                    0.000
# 2254  2023-04-04    22         0.000                    0.497
# 2255  2023-04-04    23         0.000                    0.487
#
#       Autoconsumo (kWh)            dt              dt_iso city_name   temp  \
# 0                 0.000  1.672531e+09 2023-01-01 00:00:00     local  12.93
# 1                 0.000  1.672535e+09 2023-01-01 01:00:00     local  13.49
# 2                 0.000  1.672538e+09 2023-01-01 02:00:00     local  13.55
# 3                 0.000  1.672542e+09 2023-01-01 03:00:00     local  13.61
# 4                 0.000  1.672546e+09 2023-01-01 04:00:00     local  13.59
# ...                 ...           ...                 ...       ...    ...
# 2251              0.012           NaN                 NaT       NaN    NaN
# 2252              0.000           NaN                 NaT       NaN    NaN
# 2253              0.000           NaN                 NaT       NaN    NaN
# 2254              0.000           NaN                 NaT       NaN    NaN
# 2255              0.000           NaN                 NaT       NaN    NaN
#
#       feels_like  temp_min  temp_max  pressure  sea_level  grnd_level  \
# 0          12.76     12.72     13.43    1019.0        NaN         NaN
# 1          13.38     13.43     13.90    1018.0        NaN         NaN
# 2          13.44     13.48     14.82    1017.0        NaN         NaN
# 3          13.51     12.01     14.82    1016.0        NaN         NaN
# 4          13.49     12.01     14.82    1015.0        NaN         NaN
# ...          ...       ...       ...       ...        ...         ...
# 2251         NaN       NaN       NaN       NaN        NaN         NaN
# 2252         NaN       NaN       NaN       NaN        NaN         NaN
# 2253         NaN       NaN       NaN       NaN        NaN         NaN
# 2254         NaN       NaN       NaN       NaN        NaN         NaN
# 2255         NaN       NaN       NaN       NaN        NaN         NaN
#
#       humidity  wind_speed  rain_1h  clouds_all weather_description
# 0         95.0        2.02     3.72       100.0       moderate rain
# 1         95.0        2.18     3.26       100.0       moderate rain
# 2         95.0        2.88     2.44       100.0       moderate rain
# 3         95.0        3.63     1.74       100.0       moderate rain
# 4         95.0        4.58     1.13       100.0       moderate rain
# ...        ...         ...      ...         ...                 ...
# 2251       NaN         NaN      NaN         NaN                 NaN
# 2252       NaN         NaN      NaN         NaN                 NaN
# 2253       NaN         NaN      NaN         NaN                 NaN
# 2254       NaN         NaN      NaN         NaN                 NaN
# 2255       NaN         NaN      NaN         NaN                 NaN
#
# [2256 rows x 20 columns]

# %%
sns.heatmap(df_final_v0.isnull(),yticklabels= False,  cbar = False, cmap = 'viridis')
# Out:
# <Axes: >

# %%
sns.heatmap(df_teste_v0.isnull(),yticklabels= False,  cbar = False, cmap = 'viridis')
# Out:
# <Axes: >

# %%
df_final_v1 = pd.merge(df_energia, df_meteo_temp, left_on=['Data', 'Hora'], right_on=[df_meteo_temp['dt_iso'].dt.strftime('%Y-%m-%d'),df_meteo_temp['dt_iso'].dt.hour], how='inner')
df_final_v1
# Out:
#              Data  Hora  Normal (kWh)  Horario Economico (kWh)  \
# 0      2021-09-29     0         0.000                    0.000
# 1      2021-09-29     1         0.000                    0.000
# 2      2021-09-29     2         0.000                    0.000
# 3      2021-09-29     3         0.000                    0.000
# 4      2021-09-29     4         0.000                    0.000
# ...           ...   ...           ...                      ...
# 11011  2022-12-31    19         1.693                    0.000
# 11012  2022-12-31    20         1.327                    0.000
# 11013  2022-12-31    21         0.757                    0.000
# 11014  2022-12-31    22         0.000                    0.675
# 11015  2022-12-31    23         0.000                    0.403
#
#        Autoconsumo (kWh) Injecao na rede (kWh)          dt  \
# 0                    0.0                  None  1632873600
# 1                    0.0                  None  1632877200
# 2                    0.0                  None  1632880800
# 3                    0.0                  None  1632884400
# 4                    0.0                  None  1632888000
# ...                  ...                   ...         ...
# 11011                0.0                  None  1672513200
# 11012                0.0                  None  1672516800
# 11013                0.0                  None  1672520400
# 11014                0.0                  None  1672524000
# 11015                0.0                  None  1672527600
#
#                    dt_iso city_name   temp  ...  temp_min  temp_max  pressure  \
# 0     2021-09-29 00:00:00     local  13.97  ...     11.45     14.04      1027
# 1     2021-09-29 01:00:00     local  13.48  ...     13.43     13.90      1028
# 2     2021-09-29 02:00:00     local  12.93  ...     12.72     13.43      1027
# 3     2021-09-29 03:00:00     local  12.61  ...     10.34     12.93      1027
# 4     2021-09-29 04:00:00     local  12.61  ...      9.79     12.93      1027
# ...                   ...       ...    ...  ...       ...       ...       ...
# 11011 2022-12-31 19:00:00     local  15.70  ...     15.57     15.72      1018
# 11012 2022-12-31 20:00:00     local  15.55  ...     12.72     15.70      1018
# 11013 2022-12-31 21:00:00     local  13.45  ...     12.23     13.99      1019
# 11014 2022-12-31 22:00:00     local  12.93  ...     12.23     13.43      1019
# 11015 2022-12-31 23:00:00     local  12.93  ...     12.23     13.43      1019
#
#        sea_level  grnd_level  humidity  wind_speed  rain_1h  clouds_all  \
# 0            NaN         NaN        81        1.96      NaN          87
# 1            NaN         NaN        82        1.83      NaN          91
# 2            NaN         NaN        84        1.96      NaN          93
# 3            NaN         NaN        85        1.85      NaN          95
# 4            NaN         NaN        86        1.83      NaN          93
# ...          ...         ...       ...         ...      ...         ...
# 11011        NaN         NaN        86        5.56     3.58         100
# 11012        NaN         NaN        87        4.47     4.20         100
# 11013        NaN         NaN        93        3.29     4.23         100
# 11014        NaN         NaN        94        1.49     3.90         100
# 11015        NaN         NaN        95        1.93     4.07         100
#
#         weather_description
# 0           overcast clouds
# 1           overcast clouds
# 2           overcast clouds
# 3           overcast clouds
# 4           overcast clouds
# ...                     ...
# 11011         moderate rain
# 11012  heavy intensity rain
# 11013  heavy intensity rain
# 11014         moderate rain
# 11015  heavy intensity rain
#
# [11016 rows x 21 columns]

# %%
df_teste_v1 = pd.merge(df_teste1, df_teste0_temp, left_on=['Data', 'Hora'], right_on=[ df_teste0_temp['dt_iso'].dt.strftime('%Y-%m-%d'), df_teste0_temp['dt_iso'].dt.hour], how='outer')
df_teste_v1
# Out:
#             Data  Hora  Normal (kWh)  Horario Economico (kWh)  \
# 0     2023-01-01     0         0.000                    0.467
# 1     2023-01-01     1         0.000                    0.577
# 2     2023-01-01     2         0.000                    0.346
# 3     2023-01-01     3         0.000                    0.270
# 4     2023-01-01     4         0.000                    0.252
# ...          ...   ...           ...                      ...
# 2251  2023-04-04    19         0.953                    0.000
# 2252  2023-04-04    20         0.915                    0.000
# 2253  2023-04-04    21         0.479                    0.000
# 2254  2023-04-04    22         0.000                    0.497
# 2255  2023-04-04    23         0.000                    0.487
#
#       Autoconsumo (kWh)            dt              dt_iso city_name   temp  \
# 0                 0.000  1.672531e+09 2023-01-01 00:00:00     local  12.93
# 1                 0.000  1.672535e+09 2023-01-01 01:00:00     local  13.49
# 2                 0.000  1.672538e+09 2023-01-01 02:00:00     local  13.55
# 3                 0.000  1.672542e+09 2023-01-01 03:00:00     local  13.61
# 4                 0.000  1.672546e+09 2023-01-01 04:00:00     local  13.59
# ...                 ...           ...                 ...       ...    ...
# 2251              0.012           NaN                 NaT       NaN    NaN
# 2252              0.000           NaN                 NaT       NaN    NaN
# 2253              0.000           NaN                 NaT       NaN    NaN
# 2254              0.000           NaN                 NaT       NaN    NaN
# 2255              0.000           NaN                 NaT       NaN    NaN
#
#       feels_like  temp_min  temp_max  pressure  sea_level  grnd_level  \
# 0          12.76     12.72     13.43    1019.0        NaN         NaN
# 1          13.38     13.43     13.90    1018.0        NaN         NaN
# 2          13.44     13.48     14.82    1017.0        NaN         NaN
# 3          13.51     12.01     14.82    1016.0        NaN         NaN
# 4          13.49     12.01     14.82    1015.0        NaN         NaN
# ...          ...       ...       ...       ...        ...         ...
# 2251         NaN       NaN       NaN       NaN        NaN         NaN
# 2252         NaN       NaN       NaN       NaN        NaN         NaN
# 2253         NaN       NaN       NaN       NaN        NaN         NaN
# 2254         NaN       NaN       NaN       NaN        NaN         NaN
# 2255         NaN       NaN       NaN       NaN        NaN         NaN
#
#       humidity  wind_speed  rain_1h  clouds_all weather_description
# 0         95.0        2.02     3.72       100.0       moderate rain
# 1         95.0        2.18     3.26       100.0       moderate rain
# 2         95.0        2.88     2.44       100.0       moderate rain
# 3         95.0        3.63     1.74       100.0       moderate rain
# 4         95.0        4.58     1.13       100.0       moderate rain
# ...        ...         ...      ...         ...                 ...
# 2251       NaN         NaN      NaN         NaN                 NaN
# 2252       NaN         NaN      NaN         NaN                 NaN
# 2253       NaN         NaN      NaN         NaN                 NaN
# 2254       NaN         NaN      NaN         NaN                 NaN
# 2255       NaN         NaN      NaN         NaN                 NaN
#
# [2256 rows x 20 columns]

# %%
sns.heatmap(df_final_v1.isnull(),yticklabels= False,  cbar = False, cmap = 'viridis')
# Out:
# <Axes: >

# %%
sns.heatmap(df_teste_v1.isnull(),yticklabels= False,  cbar = False, cmap = 'viridis')
# Out:
# <Axes: >

# %% [markdown]
# Opção inner

# %%
df = df_final_v1
df
# Out:
#              Data  Hora  Normal (kWh)  Horario Economico (kWh)  \
# 0      2021-09-29     0         0.000                    0.000
# 1      2021-09-29     1         0.000                    0.000
# 2      2021-09-29     2         0.000                    0.000
# 3      2021-09-29     3         0.000                    0.000
# 4      2021-09-29     4         0.000                    0.000
# ...           ...   ...           ...                      ...
# 11011  2022-12-31    19         1.693                    0.000
# 11012  2022-12-31    20         1.327                    0.000
# 11013  2022-12-31    21         0.757                    0.000
# 11014  2022-12-31    22         0.000                    0.675
# 11015  2022-12-31    23         0.000                    0.403
#
#        Autoconsumo (kWh) Injecao na rede (kWh)          dt  \
# 0                    0.0                  None  1632873600
# 1                    0.0                  None  1632877200
# 2                    0.0                  None  1632880800
# 3                    0.0                  None  1632884400
# 4                    0.0                  None  1632888000
# ...                  ...                   ...         ...
# 11011                0.0                  None  1672513200
# 11012                0.0                  None  1672516800
# 11013                0.0                  None  1672520400
# 11014                0.0                  None  1672524000
# 11015                0.0                  None  1672527600
#
#                    dt_iso city_name   temp  ...  temp_min  temp_max  pressure  \
# 0     2021-09-29 00:00:00     local  13.97  ...     11.45     14.04      1027
# 1     2021-09-29 01:00:00     local  13.48  ...     13.43     13.90      1028
# 2     2021-09-29 02:00:00     local  12.93  ...     12.72     13.43      1027
# 3     2021-09-29 03:00:00     local  12.61  ...     10.34     12.93      1027
# 4     2021-09-29 04:00:00     local  12.61  ...      9.79     12.93      1027
# ...                   ...       ...    ...  ...       ...       ...       ...
# 11011 2022-12-31 19:00:00     local  15.70  ...     15.57     15.72      1018
# 11012 2022-12-31 20:00:00     local  15.55  ...     12.72     15.70      1018
# 11013 2022-12-31 21:00:00     local  13.45  ...     12.23     13.99      1019
# 11014 2022-12-31 22:00:00     local  12.93  ...     12.23     13.43      1019
# 11015 2022-12-31 23:00:00     local  12.93  ...     12.23     13.43      1019
#
#        sea_level  grnd_level  humidity  wind_speed  rain_1h  clouds_all  \
# 0            NaN         NaN        81        1.96      NaN          87
# 1            NaN         NaN        82        1.83      NaN          91
# 2            NaN         NaN        84        1.96      NaN          93
# 3            NaN         NaN        85        1.85      NaN          95
# 4            NaN         NaN        86        1.83      NaN          93
# ...          ...         ...       ...         ...      ...         ...
# 11011        NaN         NaN        86        5.56     3.58         100
# 11012        NaN         NaN        87        4.47     4.20         100
# 11013        NaN         NaN        93        3.29     4.23         100
# 11014        NaN         NaN        94        1.49     3.90         100
# 11015        NaN         NaN        95        1.93     4.07         100
#
#         weather_description
# 0           overcast clouds
# 1           overcast clouds
# 2           overcast clouds
# 3           overcast clouds
# 4           overcast clouds
# ...                     ...
# 11011         moderate rain
# 11012  heavy intensity rain
# 11013  heavy intensity rain
# 11014         moderate rain
# 11015  heavy intensity rain
#
# [11016 rows x 21 columns]

# %%
df_teste = df_teste_v1
df_teste
# Out:
#             Data  Hora  Normal (kWh)  Horario Economico (kWh)  \
# 0     2023-01-01     0         0.000                    0.467
# 1     2023-01-01     1         0.000                    0.577
# 2     2023-01-01     2         0.000                    0.346
# 3     2023-01-01     3         0.000                    0.270
# 4     2023-01-01     4         0.000                    0.252
# ...          ...   ...           ...                      ...
# 2251  2023-04-04    19         0.953                    0.000
# 2252  2023-04-04    20         0.915                    0.000
# 2253  2023-04-04    21         0.479                    0.000
# 2254  2023-04-04    22         0.000                    0.497
# 2255  2023-04-04    23         0.000                    0.487
#
#       Autoconsumo (kWh)            dt              dt_iso city_name   temp  \
# 0                 0.000  1.672531e+09 2023-01-01 00:00:00     local  12.93
# 1                 0.000  1.672535e+09 2023-01-01 01:00:00     local  13.49
# 2                 0.000  1.672538e+09 2023-01-01 02:00:00     local  13.55
# 3                 0.000  1.672542e+09 2023-01-01 03:00:00     local  13.61
# 4                 0.000  1.672546e+09 2023-01-01 04:00:00     local  13.59
# ...                 ...           ...                 ...       ...    ...
# 2251              0.012           NaN                 NaT       NaN    NaN
# 2252              0.000           NaN                 NaT       NaN    NaN
# 2253              0.000           NaN                 NaT       NaN    NaN
# 2254              0.000           NaN                 NaT       NaN    NaN
# 2255              0.000           NaN                 NaT       NaN    NaN
#
#       feels_like  temp_min  temp_max  pressure  sea_level  grnd_level  \
# 0          12.76     12.72     13.43    1019.0        NaN         NaN
# 1          13.38     13.43     13.90    1018.0        NaN         NaN
# 2          13.44     13.48     14.82    1017.0        NaN         NaN
# 3          13.51     12.01     14.82    1016.0        NaN         NaN
# 4          13.49     12.01     14.82    1015.0        NaN         NaN
# ...          ...       ...       ...       ...        ...         ...
# 2251         NaN       NaN       NaN       NaN        NaN         NaN
# 2252         NaN       NaN       NaN       NaN        NaN         NaN
# 2253         NaN       NaN       NaN       NaN        NaN         NaN
# 2254         NaN       NaN       NaN       NaN        NaN         NaN
# 2255         NaN       NaN       NaN       NaN        NaN         NaN
#
#       humidity  wind_speed  rain_1h  clouds_all weather_description
# 0         95.0        2.02     3.72       100.0       moderate rain
# 1         95.0        2.18     3.26       100.0       moderate rain
# 2         95.0        2.88     2.44       100.0       moderate rain
# 3         95.0        3.63     1.74       100.0       moderate rain
# 4         95.0        4.58     1.13       100.0       moderate rain
# ...        ...         ...      ...         ...                 ...
# 2251       NaN         NaN      NaN         NaN                 NaN
# 2252       NaN         NaN      NaN         NaN                 NaN
# 2253       NaN         NaN      NaN         NaN                 NaN
# 2254       NaN         NaN      NaN         NaN                 NaN
# 2255       NaN         NaN      NaN         NaN                 NaN
#
# [2256 rows x 20 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# Data                         459
# Hora                          24
# Normal (kWh)                1282
# Horario Economico (kWh)      851
# Autoconsumo (kWh)            752
# Injecao na rede (kWh)          5
# dt                         11016
# dt_iso                     11016
# city_name                      1
# temp                        2382
# feels_like                  2670
# temp_min                     481
# temp_max                     545
# pressure                      41
# sea_level                      0
# grnd_level                     0
# humidity                      82
# wind_speed                   771
# rain_1h                      367
# clouds_all                   101
# weather_description            8
# dtype: int64

# %%
df['city_name']
# Out:
# 0        local
# 1        local
# 2        local
# 3        local
# 4        local
#          ...
# 11011    local
# 11012    local
# 11013    local
# 11014    local
# 11015    local
# Name: city_name, Length: 11016, dtype: object

# %%
df.drop(['city_name'], inplace=True, axis=1)
df_teste.drop(['city_name'], inplace=True, axis=1)
df.head()
# Out:
#          Data  Hora  Normal (kWh)  Horario Economico (kWh)  Autoconsumo (kWh)  \
# 0  2021-09-29     0           0.0                      0.0                0.0
# 1  2021-09-29     1           0.0                      0.0                0.0
# 2  2021-09-29     2           0.0                      0.0                0.0
# 3  2021-09-29     3           0.0                      0.0                0.0
# 4  2021-09-29     4           0.0                      0.0                0.0
#
#   Injecao na rede (kWh)          dt              dt_iso   temp  feels_like  \
# 0                  None  1632873600 2021-09-29 00:00:00  13.97       13.54
# 1                  None  1632877200 2021-09-29 01:00:00  13.48       13.02
# 2                  None  1632880800 2021-09-29 02:00:00  12.93       12.47
# 3                  None  1632884400 2021-09-29 03:00:00  12.61       12.15
# 4                  None  1632888000 2021-09-29 04:00:00  12.61       12.17
#
#    temp_min  temp_max  pressure  sea_level  grnd_level  humidity  wind_speed  \
# 0     11.45     14.04      1027        NaN         NaN        81        1.96
# 1     13.43     13.90      1028        NaN         NaN        82        1.83
# 2     12.72     13.43      1027        NaN         NaN        84        1.96
# 3     10.34     12.93      1027        NaN         NaN        85        1.85
# 4      9.79     12.93      1027        NaN         NaN        86        1.83
#
#    rain_1h  clouds_all weather_description
# 0      NaN          87     overcast clouds
# 1      NaN          91     overcast clouds
# 2      NaN          93     overcast clouds
# 3      NaN          95     overcast clouds
# 4      NaN          93     overcast clouds

# %%
# Sea_level e grnd_level são ambas colunas vazias, portanto vamos fazer drop

df.drop(['sea_level'], inplace = True, axis = 1)
df.drop(['grnd_level'], inplace = True, axis = 1)

df_teste.drop(['sea_level'], inplace = True, axis = 1)
df_teste.drop(['grnd_level'], inplace = True, axis = 1)

# %%
print(df['rain_1h'].value_counts())
print('----------------------------------------------------------------------------------------------------------------')

# temos 10278 valores vazios para este dado
print(df[df['rain_1h'].isna()])

#subestituir os valores vazios por zero
df['rain_1h'] = df['rain_1h'].map(lambda x: 0 if pd.isna(x) else x)

df_teste['rain_1h'] = df_teste['rain_1h'].map(lambda x: 0 if pd.isna(x) else x)
# Out:
# rain_1h
# 0.12    69
# 0.16    57
# 0.15    54
# 0.14    54
# 0.11    51
#         ..
# 6.36     1
# 3.54     1
# 3.89     1
# 3.65     1
# 4.07     1
# Name: count, Length: 367, dtype: int64
# ----------------------------------------------------------------------------------------------------------------
#              Data  Hora  Normal (kWh)  Horario Economico (kWh)  \
# 0      2021-09-29     0         0.000                      0.0
# 1      2021-09-29     1         0.000                      0.0
# 2      2021-09-29     2         0.000                      0.0
# 3      2021-09-29     3         0.000                      0.0
# 4      2021-09-29     4         0.000                      0.0
# ...           ...   ...           ...                      ...
# 11002  2022-12-31    10         1.074                      0.0
# 11003  2022-12-31    11         0.360                      0.0
# 11004  2022-12-31    12         0.402                      0.0
# 11006  2022-12-31    14         1.060                      0.0
# 11007  2022-12-31    15         1.340                      0.0
#
#        Autoconsumo (kWh) Injecao na rede (kWh)          dt  \
# 0                  0.000                  None  1632873600
# 1                  0.000                  None  1632877200
# 2                  0.000                  None  1632880800
# 3                  0.000                  None  1632884400
# 4                  0.000                  None  1632888000
# ...                  ...                   ...         ...
# 11002              0.057                  None  1672480800
# 11003              0.108                  None  1672484400
# 11004              0.122                  None  1672488000
# 11006              0.166                  None  1672495200
# 11007              0.039                  None  1672498800
#
#                    dt_iso   temp  feels_like  temp_min  temp_max  pressure  \
# 0     2021-09-29 00:00:00  13.97       13.54     11.45     14.04      1027
# 1     2021-09-29 01:00:00  13.48       13.02     13.43     13.90      1028
# 2     2021-09-29 02:00:00  12.93       12.47     12.72     13.43      1027
# 3     2021-09-29 03:00:00  12.61       12.15     10.34     12.93      1027
# 4     2021-09-29 04:00:00  12.61       12.17      9.79     12.93      1027
# ...                   ...    ...         ...       ...       ...       ...
# 11002 2022-12-31 10:00:00  15.18       14.40     15.10     16.68      1019
# 11003 2022-12-31 11:00:00  15.75       14.97     15.66     16.72      1019
# 11004 2022-12-31 12:00:00  16.80       16.05     15.66     16.82      1018
# 11006 2022-12-31 14:00:00  17.84       17.04     16.45     17.93      1017
# 11007 2022-12-31 15:00:00  17.35       16.81     16.68     17.37      1017
#
#        humidity  wind_speed  rain_1h  clouds_all weather_description
# 0            81        1.96      NaN          87     overcast clouds
# 1            82        1.83      NaN          91     overcast clouds
# 2            84        1.96      NaN          93     overcast clouds
# 3            85        1.85      NaN          95     overcast clouds
# 4            86        1.83      NaN          93     overcast clouds
# ...         ...         ...      ...         ...                 ...
# 11002        63        6.98      NaN          65       broken clouds
# 11003        61        7.74      NaN          69       broken clouds
# 11004        58        7.64      NaN          46    scattered clouds
# 11006        52        6.73      NaN          41    scattered clouds
# 11007        64        8.35      NaN          77       broken clouds
#
# [8732 rows x 18 columns]

# %%
sns.heatmap(df.isnull(),yticklabels= False,  cbar = False, cmap = 'viridis')
# Out:
# <Axes: >

# %%
sns.heatmap(df_teste.isnull(),yticklabels= False,  cbar = False, cmap = 'viridis')
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11016 entries, 0 to 11015
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Data                     11016 non-null  object
#  1   Hora                     11016 non-null  int64
#  2   Normal (kWh)             11016 non-null  float64
#  3   Horario Economico (kWh)  11016 non-null  float64
#  4   Autoconsumo (kWh)        11016 non-null  float64
#  5   Injecao na rede (kWh)    11016 non-null  object
#  6   dt                       11016 non-null  int64
#  7   dt_iso                   11016 non-null  datetime64[ns]
#  8   temp                     11016 non-null  float64
#  9   feels_like               11016 non-null  float64
#  10  temp_min                 11016 non-null  float64
#  11  temp_max                 11016 non-null  float64
#  12  pressure                 11016 non-null  int64
#  13  humidity                 11016 non-null  int64
#  14  wind_speed               11016 non-null  float64
#  15  rain_1h                  11016 non-null  float64
#  16  clouds_all               11016 non-null  int64
#  17  weather_description      11016 non-null  object
# dtypes: datetime64[ns](1), float64(9), int64(5), object(3)
# memory usage: 1.5+ MB

# %%
df.drop(['Data'], inplace = True, axis = 1)
df.drop(['Hora'], inplace = True, axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11016 entries, 0 to 11015
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Normal (kWh)             11016 non-null  float64
#  1   Horario Economico (kWh)  11016 non-null  float64
#  2   Autoconsumo (kWh)        11016 non-null  float64
#  3   Injecao na rede (kWh)    11016 non-null  object
#  4   dt                       11016 non-null  int64
#  5   dt_iso                   11016 non-null  datetime64[ns]
#  6   temp                     11016 non-null  float64
#  7   feels_like               11016 non-null  float64
#  8   temp_min                 11016 non-null  float64
#  9   temp_max                 11016 non-null  float64
#  10  pressure                 11016 non-null  int64
#  11  humidity                 11016 non-null  int64
#  12  wind_speed               11016 non-null  float64
#  13  rain_1h                  11016 non-null  float64
#  14  clouds_all               11016 non-null  int64
#  15  weather_description      11016 non-null  object
# dtypes: datetime64[ns](1), float64(9), int64(4), object(2)
# memory usage: 1.3+ MB

# %%
#df['Year']   = df['dt_iso'].dt.year
df['Month']  = df['dt_iso'].dt.month
df['Day']    = df['dt_iso'].dt.day

df['Hour']   = df['dt_iso'].dt.hour
df['Minute'] = df['dt_iso'].dt.minute
df['Second'] = df['dt_iso'].dt.second

df_teste['Data'] = pd.to_datetime((df_teste["Data"]))
df_teste['Data'].dt.strftime('%Y-%m-%d')

#df_teste['Year']   = df_teste['Data'].dt.year
df_teste['Month']  = df_teste['Data'].dt.month
df_teste['Day']    = df_teste['Data'].dt.day
df_teste['Hour']   = df_teste['Hora']

# %%
df['Dia da Semana'] = df['dt_iso'].map(lambda x: x.weekday())
df_teste['Dia da Semana'] = df_teste['Data'].map(lambda x: x.weekday())
df['Dia da Semana'].value_counts()
# Out:
# Dia da Semana
# 2    1584
# 3    1584
# 4    1584
# 5    1584
# 6    1560
# 0    1560
# 1    1560
# Name: count, dtype: int64

# %%
def obter_estacao(do):
    if (do.month == 3 and do.day >= 20) or do.month == 4 or do.month == 5 or (do.month == 6 and do.day <21):
        return 1  # Primavera
    if (do.month == 6 and do.day >= 21) or do.month == 7 or do.month == 8 or (do.month == 9 and do.day <22):
        return 0  # Verão
    if (do.month == 9 and do.day >= 22) or do.month == 10 or do.month == 11 or (do.month == 12 and do.day <22):
        return 2  # Outono
    else:
        return 3  # Inverno

# %%
# Criando a coluna 'feriado' com valores iniciais iguais a 0
df['feriado'] = 0

# Lista de feriados fixos
feriados_fixos = ['01-01', '04-25', '05-01', '06-10', '08-15', '10-05', '11-01', '12-01', '12-08', '12-25']

# Adicionando feriados fixos
for feriado in feriados_fixos:
    df.loc[df['dt_iso'].dt.strftime('%m-%d') == feriado, 'feriado'] = 1

# Adicionando Sexta-feira Santa
sexta_santa_dates = ['2021-04-02', '2022-04-15']
df.loc[df['dt_iso'].isin(sexta_santa_dates), 'feriado'] = 1

# Adicionando Páscoa
pascoa_dates = ['2021-04-04', '2022-03-27']
df.loc[df['dt_iso'].isin(pascoa_dates), 'feriado'] = 1

df['feriado'].value_counts()
# Out:
# feriado
# 0    10654
# 1      362
# Name: count, dtype: int64

# %%
# Criando a coluna 'feriado' com valores iniciais iguais a 0
df_teste['feriado'] = 0

# Lista de feriados fixos
feriados_fixos = ['01-01', '04-25', '05-01', '06-10', '08-15', '10-05', '11-01', '12-01', '12-08', '12-25']

# Adicionando feriados fixos
for feriado in feriados_fixos:
    df_teste.loc[df_teste['Data'].dt.strftime('%m-%d') == feriado, 'feriado'] = 1

# Adicionando Sexta-feira Santa
sexta_santa_dates = ['2023-04-07']
df_teste.loc[df_teste['Data'].isin(sexta_santa_dates), 'feriado'] = 1

# Adicionando Páscoa
pascoa_dates = ['2023-04-16']
df_teste.loc[df_teste['Data'].isin(pascoa_dates), 'feriado'] = 1

df_teste['feriado'].value_counts()
# Out:
# feriado
# 0    2232
# 1      24
# Name: count, dtype: int64

# %%
# verão = 0, primavera = 1, outono = 2, inverno = 3
df      ['estacao do ano'] = df['dt_iso'].apply(obter_estacao)
df_teste['estacao do ano'] = df_teste['Data'].apply(obter_estacao)

df['estacao do ano'].astype('category')
df_teste['estacao do ano'].astype('category')
df['estacao do ano'].value_counts()
# Out:
# estacao do ano
# 2    4200
# 3    2352
# 1    2232
# 0    2232
# Name: count, dtype: int64

# %%
df_teste.drop(['Data'], inplace = True, axis = 1)
df_teste.drop(['Hora'], inplace = True, axis = 1)

# %%
df.drop('dt_iso', inplace=True, axis=1)
df_teste.drop('dt_iso', inplace=True, axis=1)

# %%
df['weather_description'].value_counts()
# Out:
# weather_description
# sky is clear            3010
# overcast clouds         2430
# light rain              1662
# broken clouds           1413
# scattered clouds        1148
# few clouds               731
# moderate rain            562
# heavy intensity rain      60
# Name: count, dtype: int64

# %%
# Criar os atributos binários
df['sky is clear']             = ( df['weather_description'].str.contains('sky is clear') ).astype(int)
df['overcast clouds']          = ( df['weather_description'].str.contains('overcast clouds') ).astype(int)
df['light rain']               = ( df['weather_description'].str.contains('light rain') ).astype(int)
df['broken clouds']            = ( df['weather_description'].str.contains('broken clouds') ).astype(int)
df['scattered clouds']         = ( df['weather_description'].str.contains('scattered clouds') ).astype(int)
df['few clouds']               = ( df['weather_description'].str.contains('few clouds') ).astype(int)
df['moderate rain']            = ( df['weather_description'].str.contains('moderate rain') ).astype(int)
df['heavy intensity rain']     = ( df['weather_description'].str.contains('heavy intensity rain') ).astype(int)

df_teste['sky is clear']             = ( df['weather_description'].str.contains('sky is clear') ).astype(int)
df_teste['overcast clouds']          = ( df['weather_description'].str.contains('overcast clouds') ).astype(int)
df_teste['light rain']               = ( df['weather_description'].str.contains('light rain') ).astype(int)
df_teste['broken clouds']            = ( df['weather_description'].str.contains('broken clouds') ).astype(int)
df_teste['scattered clouds']         = ( df['weather_description'].str.contains('scattered clouds') ).astype(int)
df_teste['few clouds']               = ( df['weather_description'].str.contains('few clouds') ).astype(int)
df_teste['moderate rain']            = ( df['weather_description'].str.contains('moderate rain') ).astype(int)
df_teste['heavy intensity rain']     = ( df['weather_description'].str.contains('heavy intensity rain') ).astype(int)

# %%
df.drop(['weather_description'], inplace = True, axis = 1)

df_teste.drop(['weather_description'], inplace = True, axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11016 entries, 0 to 11015
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Normal (kWh)             11016 non-null  float64
#  1   Horario Economico (kWh)  11016 non-null  float64
#  2   Autoconsumo (kWh)        11016 non-null  float64
#  3   Injecao na rede (kWh)    11016 non-null  object
#  4   dt                       11016 non-null  int64
#  5   temp                     11016 non-null  float64
#  6   feels_like               11016 non-null  float64
#  7   temp_min                 11016 non-null  float64
#  8   temp_max                 11016 non-null  float64
#  9   pressure                 11016 non-null  int64
#  10  humidity                 11016 non-null  int64
#  11  wind_speed               11016 non-null  float64
#  12  rain_1h                  11016 non-null  float64
#  13  clouds_all               11016 non-null  int64
#  14  Month                    11016 non-null  int32
#  15  Day                      11016 non-null  int32
#  16  Hour                     11016 non-null  int32
#  17  Minute                   11016 non-null  int32
#  18  Second                   11016 non-null  int32
#  19  Dia da Semana            11016 non-null  int64
#  20  feriado                  11016 non-null  int64
#  21  estacao do ano           11016 non-null  int64
#  22  sky is clear             11016 non-null  int32
#  23  overcast clouds          11016 non-null  int32
#  24  light rain               11016 non-null  int32
#  25  broken clouds            11016 non-null  int32
#  26  scattered clouds         11016 non-null  int32
#  27  few clouds               11016 non-null  int32
#  28  moderate rain            11016 non-null  int32
#  29  heavy intensity rain     11016 non-null  int32
# dtypes: float64(9), int32(13), int64(7), object(1)
# memory usage: 2.0+ MB

# %%
df.nunique()
# Out:
# Normal (kWh)                1282
# Horario Economico (kWh)      851
# Autoconsumo (kWh)            752
# Injecao na rede (kWh)          5
# dt                         11016
# temp                        2382
# feels_like                  2670
# temp_min                     481
# temp_max                     545
# pressure                      41
# humidity                      82
# wind_speed                   771
# rain_1h                      368
# clouds_all                   101
# Month                         12
# Day                           31
# Hour                          24
# Minute                         1
# Second                         1
# Dia da Semana                  7
# feriado                        2
# estacao do ano                 4
# sky is clear                   2
# overcast clouds                2
# light rain                     2
# broken clouds                  2
# scattered clouds               2
# few clouds                     2
# moderate rain                  2
# heavy intensity rain           2
# dtype: int64

# %%
# dt é um time stamp em Unix time ou Epoch time.
# O Unix time é uma forma de medir o tempo como o número de segundos decorridos desde a meia-noite UTC
# (Coordinated Universal Time) de 1º de janeiro de 1970, excluindo segundos bissextos.
# Cada número inteiro representa um segundo adicional.
# ou seja poderiamos converter para o formato ano-mês-dia-hora-minuto mas não é precisso pois já temos esse dados, ou seja
# podemos dar drop

df.drop('dt', inplace=True, axis=1)

df_teste.drop('dt', inplace=True, axis=1)

# %%
#correlação com temp é quase 1 logo devemos apaga-los

df.drop('feels_like', inplace=True, axis=1)
df.drop('temp_min', inplace=True, axis=1)
df.drop('temp_max', inplace=True, axis=1)

df_teste.drop('feels_like', inplace=True, axis=1)
df_teste.drop('temp_min', inplace=True, axis=1)
df_teste.drop('temp_max', inplace=True, axis=1)

# %%
"""
df['pressure']   = (df['pressure'] - df['pressure'].min()) / (df['pressure'].max() - df['pressure'].min())
df['humidity']   = (df['humidity'] - df['humidity'].min()) / (df['humidity'].max() - df['humidity'].min())
df['clouds_all'] = (df['clouds_all'] - df['clouds_all'].min()) / (df['clouds_all'].max() - df['clouds_all'].min())
df['temp']       = (df['temp'] - df['temp'].min()) / (df['temp'].max() - df['temp'].min())
df['Hour']       = (df['Hour'] - df['Hour'].min()) / (df['Hour'].max() - df['Hour'].min())"""
df.describe()
# Out:
#        Normal (kWh)  Horario Economico (kWh)  Autoconsumo (kWh)          temp  \
# count  11016.000000             11016.000000       11016.000000  11016.000000
# mean       0.202278                 0.159714           0.117314     16.182991
# std        0.349478                 0.271792           0.176762      5.756972
# min        0.000000                 0.000000           0.000000      0.320000
# 25%        0.000000                 0.000000           0.000000     12.080000
# 50%        0.000000                 0.000000           0.000000     15.625000
# 75%        0.314000                 0.288000           0.227000     19.270000
# max        3.251000                 6.978000           1.192000     40.850000
#
#            pressure      humidity    wind_speed       rain_1h    clouds_all  \
# count  11016.000000  11016.000000  11016.000000  11016.000000  11016.000000
# mean    1018.396605     76.570715      2.672039      0.185905     54.000908
# std        6.203379     16.268260      1.476158      0.611241     40.553002
# min      994.000000     19.000000      0.060000      0.000000      0.000000
# 25%     1015.000000     66.000000      1.620000      0.000000      7.000000
# 50%     1018.000000     81.000000      2.400000      0.000000     60.000000
# 75%     1022.000000     91.000000      3.420000      0.000000     98.000000
# max     1034.000000    100.000000     11.100000      7.450000    100.000000
#
#               Month  ...       feriado  estacao do ano  sky is clear  \
# count  11016.000000  ...  11016.000000    11016.000000  11016.000000
# mean       7.433551  ...      0.032861        1.605664      0.273239
# std        3.578335  ...      0.178282        1.034976      0.445643
# min        1.000000  ...      0.000000        0.000000      0.000000
# 25%        4.000000  ...      0.000000        1.000000      0.000000
# 50%        8.000000  ...      0.000000        2.000000      0.000000
# 75%       11.000000  ...      0.000000        2.000000      1.000000
# max       12.000000  ...      1.000000        3.000000      1.000000
#
#        overcast clouds    light rain  broken clouds  scattered clouds  \
# count     11016.000000  11016.000000   11016.000000      11016.000000
# mean          0.220588      0.150871       0.128268          0.104212
# std           0.414662      0.357940       0.334403          0.305549
# min           0.000000      0.000000       0.000000          0.000000
# 25%           0.000000      0.000000       0.000000          0.000000
# 50%           0.000000      0.000000       0.000000          0.000000
# 75%           0.000000      0.000000       0.000000          0.000000
# max           1.000000      1.000000       1.000000          1.000000
#
#          few clouds  moderate rain  heavy intensity rain
# count  11016.000000   11016.000000          11016.000000
# mean       0.066358       0.051017              0.005447
# std        0.248918       0.220042              0.073603
# min        0.000000       0.000000              0.000000
# 25%        0.000000       0.000000              0.000000
# 50%        0.000000       0.000000              0.000000
# 75%        0.000000       0.000000              0.000000
# max        1.000000       1.000000              1.000000
#
# [8 rows x 25 columns]

# %%
df['Injecao na rede (kWh)'].value_counts()
# Out:
# Injecao na rede (kWh)
# None         7777
# High         1103
# Medium       1098
# Very High     606
# Low           432
# Name: count, dtype: int64

# %%
#fazer label encoding

categoria_para_numero = {'None': 0, 'Low': 1, 'Medium': 2, 'High': 3, 'Very High': 4}
df['Injecao na rede (kWh)'] = df['Injecao na rede (kWh)'].map(categoria_para_numero)

# %%
df.drop('Minute', inplace=True, axis=1)
df.drop('Second', inplace=True, axis=1)

# %%
X = df.drop('Injecao na rede (kWh)', axis = 1)
y = df['Injecao na rede (kWh)']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 2022)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11016 entries, 0 to 11015
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Normal (kWh)             11016 non-null  float64
#  1   Horario Economico (kWh)  11016 non-null  float64
#  2   Autoconsumo (kWh)        11016 non-null  float64
#  3   Injecao na rede (kWh)    11016 non-null  int64
#  4   temp                     11016 non-null  float64
#  5   pressure                 11016 non-null  int64
#  6   humidity                 11016 non-null  int64
#  7   wind_speed               11016 non-null  float64
#  8   rain_1h                  11016 non-null  float64
#  9   clouds_all               11016 non-null  int64
#  10  Month                    11016 non-null  int32
#  11  Day                      11016 non-null  int32
#  12  Hour                     11016 non-null  int32
#  13  Dia da Semana            11016 non-null  int64
#  14  feriado                  11016 non-null  int64
#  15  estacao do ano           11016 non-null  int64
#  16  sky is clear             11016 non-null  int32
#  17  overcast clouds          11016 non-null  int32
#  18  light rain               11016 non-null  int32
#  19  broken clouds            11016 non-null  int32
#  20  scattered clouds         11016 non-null  int32
#  21  few clouds               11016 non-null  int32
#  22  moderate rain            11016 non-null  int32
#  23  heavy intensity rain     11016 non-null  int32
# dtypes: float64(6), int32(11), int64(7)
# memory usage: 1.6 MB

# %%
sns.heatmap(df_teste.isnull(),yticklabels= False,  cbar = False, cmap = 'viridis')
# Out:
# <Axes: >

# %%
# Crie um objeto XGBClassifier
estimator = XGBClassifier()

# Defina os parâmetros para o Grid Search
param_grid = {
    'objective': ['softmax'],
    'tree_method': ['hist'],
    'learning_rate': [0.09],
    'n_estimators': [200, 250],
    'max_depth': [5, 7],
    'min_child_weight': [0],
    'subsample': [1.0],
    'colsample_bytree': [1.0],
    'colsample_bylevel': [1.0],
    'colsample_bynode': [1.0],
    'gamma': [0.0]
}

kf = KFold(n_splits = 10, shuffle = True, random_state = 20)  

# Crie o objeto GridSearchCV
grid = GridSearchCV(estimator, param_grid,refit=True, scoring='top_k_accuracy',verbose=2,cv=kf,n_jobs=-1)

# Ajuste o modelo aos dados de treino
grid.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# d:\Programs\miniconda3\envs\dados\lib\site-packages\sklearn\model_selection\_search.py:979: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan]
#   warnings.warn(
# GridSearchCV(cv=KFold(n_splits=10, random_state=20, shuffle=True),
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      in...
#                                      n_jobs=None, num_parallel_tree=None,
#                                      random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'colsample_bylevel': [1.0], 'colsample_bynode': [1.0],
#                          'colsample_bytree': [1.0], 'gamma': [0.0],
#                          'learning_rate': [0.09], 'max_depth': [5, 7],
#                          'min_child_weight': [0], 'n_estimators': [200, 250],
#                          'objective': ['softmax'], 'subsample': [1.0],
#                          'tree_method': ['hist']},
#              scoring='top_k_accuracy', verbose=2)

# %%
grid.best_params_
# Out:
# {'colsample_bylevel': 1.0,
#  'colsample_bynode': 1.0,
#  'colsample_bytree': 1.0,
#  'gamma': 0.0,
#  'learning_rate': 0.09,
#  'max_depth': 5,
#  'min_child_weight': 0,
#  'n_estimators': 200,
#  'objective': 'softmax',
#  'subsample': 1.0,
#  'tree_method': 'hist'}

# %%
grid.best_estimator_
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=1.0, colsample_bynode=1.0, colsample_bytree=1.0,
#               device=None, early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0.0, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.09, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#               max_leaves=None, min_child_weight=0, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=200,
#               n_jobs=None, num_parallel_tree=None, objective='multi:softprob', ...)

# %%
from sklearn.metrics import explained_variance_score, r2_score, mean_absolute_percentage_error 
from sklearn import metrics
grid_predictions = grid.predict(X_test)
print ( explained_variance_score(y_test, grid_predictions) )
print ( r2_score(y_test, grid_predictions) )
print(mean_absolute_percentage_error(y_test, grid_predictions))

print('MAE:', metrics.mean_absolute_error(y_test, grid_predictions))
print('MSE:', metrics.mean_squared_error(y_test, grid_predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, grid_predictions)))
# Out:
# 0.9010078919760901
# 0.9008176112592834
# 96749038893587.12
# MAE: 0.1340393343419062
# MSE: 0.16611195158850228
# RMSE: 0.4075683397769045

# %%
SaveModel("Modelos_Carlos/xgb_classifier_GridSearch_Feriados_Pred13", grid)
model = UseModel("Modelos_Carlos/xgb_classifier_GridSearch_Feriados_Pred13")

# %%
#xgb_score = model.score(X_test,y_test)

# %%
#print("Acuracy :)) = %.2f%%" %(xgb_score * 100) )

# %%
xgb_predicions = model.predict(X_test)

# %%
print( classification_report(y_test, xgb_predicions) )
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      2311
#            1       0.48      0.22      0.30       153
#            2       0.59      0.66      0.62       315
#            3       0.69      0.74      0.71       331
#            4       0.82      0.81      0.81       195
#
#     accuracy                           0.88      3305
#    macro avg       0.71      0.68      0.68      3305
# weighted avg       0.87      0.88      0.88      3305

# %%
kaggleMaker(df_teste,model,13)
