# %%
import sklearn as skl
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing

# %%
df = pd.read_csv("Portugal 2022-08-01 to 2023-08-01.csv")

# %%
df.columns
# Out:
# Index(['name', 'datetime', 'tempmax', 'tempmin', 'temp', 'feelslikemax',
#        'feelslikemin', 'feelslike', 'dew', 'humidity', 'precip', 'precipprob',
#        'precipcover', 'preciptype', 'snow', 'snowdepth', 'windgust',
#        'windspeed', 'winddir', 'sealevelpressure', 'cloudcover', 'visibility',
#        'solarradiation', 'solarenergy', 'uvindex', 'severerisk', 'sunrise',
#        'sunset', 'moonphase', 'conditions', 'description', 'icon', 'stations'],
#       dtype='object')

# %%
df.nunique()
# Out:
# name                  1
# datetime            366
# tempmax             145
# tempmin             131
# temp                152
# feelslikemax        141
# feelslikemin        140
# feelslike           157
# dew                 145
# humidity            260
# precip               86
# precipprob            2
# precipcover           6
# preciptype            1
# snow                  1
# snowdepth             1
# windgust            103
# windspeed           178
# winddir             338
# sealevelpressure    181
# cloudcover          295
# visibility           48
# solarradiation      346
# solarenergy         206
# uvindex              11
# severerisk            2
# sunrise             366
# sunset              366
# moonphase            93
# conditions            5
# description          19
# icon                  3
# stations              6
# dtype: int64

# %%
df.head()
# Out:
#        name    datetime  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# 0  Portugal  2022-08-01     30.4     19.9  25.6          30.6          19.9
# 1  Portugal  2022-08-02     31.0     17.7  22.6          31.4          17.7
# 2  Portugal  2022-08-03     28.0     19.0  22.3          28.6          19.0
# 3  Portugal  2022-08-04     25.3     19.2  21.1          25.3          19.2
# 4  Portugal  2022-08-05     26.8     18.6  21.3          27.4          18.6
#
#    feelslike   dew  humidity  ...  solarenergy  uvindex  severerisk  \
# 0       25.7  15.6      55.1  ...         19.3        9          10
# 1       22.7  16.9      71.9  ...         14.5        9          10
# 2       22.4  16.9      72.7  ...          7.2        3          10
# 3       21.1  17.1      78.5  ...          7.1        3          10
# 4       21.4  17.0      77.7  ...          8.9        4          10
#
#                sunrise               sunset  moonphase        conditions  \
# 0  2022-08-01T06:37:52  2022-08-01T20:47:33       0.13             Clear
# 1  2022-08-02T06:38:44  2022-08-02T20:46:32       0.16  Partially cloudy
# 2  2022-08-03T06:39:37  2022-08-03T20:45:29       0.20  Partially cloudy
# 3  2022-08-04T06:40:30  2022-08-04T20:44:25       0.23  Partially cloudy
# 4  2022-08-05T06:41:23  2022-08-05T20:43:20       0.25  Partially cloudy
#
#                             description               icon  \
# 0  Clear conditions throughout the day.          clear-day
# 1            Clearing in the afternoon.  partly-cloudy-day
# 2            Clearing in the afternoon.  partly-cloudy-day
# 3     Partly cloudy throughout the day.  partly-cloudy-day
# 4     Partly cloudy throughout the day.  partly-cloudy-day
#
#                                             stations
# 0  08535099999,08532099999,08534099999,D7126,0853...
# 1  08535099999,08532099999,08534099999,D7126,0853...
# 2  08535099999,08532099999,08534099999,D7126,0853...
# 3  08535099999,08532099999,08534099999,D7126,0853...
# 4  08535099999,08532099999,08534099999,D7126,0853...
#
# [5 rows x 33 columns]

# %%
df.describe()
# Out:
#           tempmax     tempmin        temp  feelslikemax  feelslikemin  \
# count  366.000000  366.000000  366.000000    366.000000    366.000000
# mean    22.170219   14.040164   17.633333     22.124044     13.771038
# std      5.409258    4.440893    4.444690      5.342276      4.942833
# min     11.300000    2.600000    7.500000     11.300000      0.100000
# 25%     17.925000   11.000000   14.400000     17.925000     11.000000
# 50%     22.600000   15.000000   18.150000     22.600000     15.000000
# 75%     26.500000   17.675000   21.300000     26.375000     17.675000
# max     36.100000   22.300000   28.000000     36.100000     22.300000
#
#         feelslike         dew    humidity      precip  precipprob  ...  \
# count  366.000000  366.000000  366.000000  366.000000  366.000000  ...
# mean    17.509290   12.212295   73.609016    1.358077   29.781421  ...
# std      4.673284    4.275984   14.262406    5.396396   45.792340  ...
# min      5.300000   -1.400000   26.100000    0.000000    0.000000  ...
# 25%     14.400000    9.700000   65.875000    0.000000    0.000000  ...
# 50%     18.150000   13.400000   72.900000    0.000000    0.000000  ...
# 75%     21.300000   15.400000   84.475000    0.095000  100.000000  ...
# max     28.000000   19.900000   99.800000   60.570000  100.000000  ...
#
#         windspeed     winddir  sealevelpressure  cloudcover  visibility  \
# count  366.000000  366.000000        366.000000  366.000000  366.000000
# mean    22.940437  244.606831       1017.989891   41.038251   10.286612
# std      6.470541  110.121673          5.562460   22.861156    0.881662
# min      7.400000    0.800000        998.400000    0.000000    3.800000
# 25%     18.400000  209.875000       1014.700000   25.475000   10.200000
# 50%     22.200000  279.100000       1017.600000   39.900000   10.500000
# 75%     26.200000  331.450000       1021.350000   57.700000   10.500000
# max     45.000000  359.900000       1032.700000   91.100000   12.500000
#
#        solarradiation  solarenergy     uvindex  severerisk   moonphase
# count      366.000000   366.000000  366.000000  366.000000  366.000000
# mean       183.312568    15.837705    6.581967   10.273224    0.474344
# std         90.978147     7.853592    2.406066    2.324779    0.286268
# min          5.300000     0.500000    0.000000   10.000000    0.000000
# 25%        101.850000     8.800000    5.000000   10.000000    0.232500
# 50%        177.600000    15.300000    7.000000   10.000000    0.470000
# 75%        262.375000    22.775000    9.000000   10.000000    0.720000
# max        354.000000    30.500000   10.000000   30.000000    0.970000
#
# [8 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 33 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              366 non-null    object
#  1   datetime          366 non-null    object
#  2   tempmax           366 non-null    float64
#  3   tempmin           366 non-null    float64
#  4   temp              366 non-null    float64
#  5   feelslikemax      366 non-null    float64
#  6   feelslikemin      366 non-null    float64
#  7   feelslike         366 non-null    float64
#  8   dew               366 non-null    float64
#  9   humidity          366 non-null    float64
#  10  precip            366 non-null    float64
#  11  precipprob        366 non-null    int64
#  12  precipcover       366 non-null    float64
#  13  preciptype        148 non-null    object
#  14  snow              366 non-null    int64
#  15  snowdepth         366 non-null    int64
#  16  windgust          366 non-null    float64
#  17  windspeed         366 non-null    float64
#  18  winddir           366 non-null    float64
#  19  sealevelpressure  366 non-null    float64
#  20  cloudcover        366 non-null    float64
#  21  visibility        366 non-null    float64
#  22  solarradiation    366 non-null    float64
#  23  solarenergy       366 non-null    float64
#  24  uvindex           366 non-null    int64
#  25  severerisk        366 non-null    int64
#  26  sunrise           366 non-null    object
#  27  sunset            366 non-null    object
#  28  moonphase         366 non-null    float64
#  29  conditions        366 non-null    object
#  30  description       366 non-null    object
#  31  icon              366 non-null    object
#  32  stations          366 non-null    object
# dtypes: float64(19), int64(5), object(9)
# memory usage: 94.5+ KB

# %%
# ver se existem linhas duplicadas se sim apager se não não fazer nada
print ( df.duplicated().sum() ) # não existem duplicadas por isso não fazemos nada
# Out:
# 0

# %%
# verificar que na coluna name apenas temos um nome ou seja podemos apagar esta coluna pois não trará nada de novo para o modelo
print ( df['name'].describe() )
df.drop(['name'], inplace = True, axis = 1) # apaga-mos a coluna 'name'
df.head() #verificamos que a coluna não existe mais
# Out:
# count          366
# unique           1
# top       Portugal
# freq           366
# Name: name, dtype: object
#      datetime  tempmax  tempmin  temp  feelslikemax  feelslikemin  feelslike  \
# 0  2022-08-01     30.4     19.9  25.6          30.6          19.9       25.7
# 1  2022-08-02     31.0     17.7  22.6          31.4          17.7       22.7
# 2  2022-08-03     28.0     19.0  22.3          28.6          19.0       22.4
# 3  2022-08-04     25.3     19.2  21.1          25.3          19.2       21.1
# 4  2022-08-05     26.8     18.6  21.3          27.4          18.6       21.4
#
#     dew  humidity  precip  ...  solarenergy  uvindex severerisk  \
# 0  15.6      55.1     0.0  ...         19.3        9         10
# 1  16.9      71.9     0.0  ...         14.5        9         10
# 2  16.9      72.7     0.0  ...          7.2        3         10
# 3  17.1      78.5     0.0  ...          7.1        3         10
# 4  17.0      77.7     0.0  ...          8.9        4         10
#
#                sunrise               sunset  moonphase        conditions  \
# 0  2022-08-01T06:37:52  2022-08-01T20:47:33       0.13             Clear
# 1  2022-08-02T06:38:44  2022-08-02T20:46:32       0.16  Partially cloudy
# 2  2022-08-03T06:39:37  2022-08-03T20:45:29       0.20  Partially cloudy
# 3  2022-08-04T06:40:30  2022-08-04T20:44:25       0.23  Partially cloudy
# 4  2022-08-05T06:41:23  2022-08-05T20:43:20       0.25  Partially cloudy
#
#                             description               icon  \
# 0  Clear conditions throughout the day.          clear-day
# 1            Clearing in the afternoon.  partly-cloudy-day
# 2            Clearing in the afternoon.  partly-cloudy-day
# 3     Partly cloudy throughout the day.  partly-cloudy-day
# 4     Partly cloudy throughout the day.  partly-cloudy-day
#
#                                             stations
# 0  08535099999,08532099999,08534099999,D7126,0853...
# 1  08535099999,08532099999,08534099999,D7126,0853...
# 2  08535099999,08532099999,08534099999,D7126,0853...
# 3  08535099999,08532099999,08534099999,D7126,0853...
# 4  08535099999,08532099999,08534099999,D7126,0853...
#
# [5 rows x 32 columns]

# %%
# ver se existem celulas vazias e se existirem temos de decidir preencher ou apagalas
sns.heatmap(df.isnull(),yticklabels= False,  cbar = False, cmap = 'viridis')
# Out:
# <Axes: >

# %%
# analisar a coluna preciptype e tentar chegar a uma decisão em o que fazer
print(df['preciptype'])
print('\n')
print ( df['preciptype'].describe() )
print('\n')
print ( df['preciptype'].value_counts() )
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 361     NaN
# 362     NaN
# 363     NaN
# 364     NaN
# 365    rain
# Name: preciptype, Length: 366, dtype: object
#
#
# count      148
# unique       1
# top       rain
# freq       148
# Name: preciptype, dtype: object
#
#
# preciptype
# rain    148
# Name: count, dtype: int64

# %%
# Decidimos como temos muitas entradas em branco que devemos apagar a coluna

df.drop(['preciptype'], inplace = True, axis = 1) # apaga-mos a coluna 'preciptype'

# %%
# ver se existem celulas vazias e se existirem temos de decidir preencher ou apagalas
sns.heatmap(df.isnull(),yticklabels= False,  cbar = False, cmap = 'viridis')
# Out:
# <Axes: >

# %%
df.drop(['datetime'], inplace = True, axis = 1) # apaga-mos a coluna 'datetime' pois já temos essa informação
print (df.info()) #verificarmos que o datetime foi eliminado
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 30 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   tempmax           366 non-null    float64
#  1   tempmin           366 non-null    float64
#  2   temp              366 non-null    float64
#  3   feelslikemax      366 non-null    float64
#  4   feelslikemin      366 non-null    float64
#  5   feelslike         366 non-null    float64
#  6   dew               366 non-null    float64
#  7   humidity          366 non-null    float64
#  8   precip            366 non-null    float64
#  9   precipprob        366 non-null    int64
#  10  precipcover       366 non-null    float64
#  11  snow              366 non-null    int64
#  12  snowdepth         366 non-null    int64
#  13  windgust          366 non-null    float64
#  14  windspeed         366 non-null    float64
#  15  winddir           366 non-null    float64
#  16  sealevelpressure  366 non-null    float64
#  17  cloudcover        366 non-null    float64
#  18  visibility        366 non-null    float64
#  19  solarradiation    366 non-null    float64
#  20  solarenergy       366 non-null    float64
#  21  uvindex           366 non-null    int64
#  22  severerisk        366 non-null    int64
#  23  sunrise           366 non-null    object
#  24  sunset            366 non-null    object
#  25  moonphase         366 non-null    float64
#  26  conditions        366 non-null    object
#  27  description       366 non-null    object
#  28  icon              366 non-null    object
#  29  stations          366 non-null    object
# dtypes: float64(19), int64(5), object(6)
# memory usage: 85.9+ KB
# None

# %%
df['sunrise'] = pd.to_datetime(df['sunrise'])

# Criando colunas para dia, mês, ano, hora de o sol se levantar, minuto de o sol se levantar, segundo de o sol se levantar
df['Year']   = df['sunrise'].dt.year
df['Day']    = df['sunrise'].dt.day
df['Month']  = df['sunrise'].dt.month

df['hour_rise']   = df['sunrise'].dt.hour
df['minute_rise'] = df['sunrise'].dt.minute
df['second_rise'] = df['sunrise'].dt.second

df.drop(['sunrise'], inplace = True, axis = 1) # apaga-mos a coluna 'sunrise' pois já temos essa informação

print (df.info()) #verificarmos que o sunrise foi eliminado
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 35 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   tempmax           366 non-null    float64
#  1   tempmin           366 non-null    float64
#  2   temp              366 non-null    float64
#  3   feelslikemax      366 non-null    float64
#  4   feelslikemin      366 non-null    float64
#  5   feelslike         366 non-null    float64
#  6   dew               366 non-null    float64
#  7   humidity          366 non-null    float64
#  8   precip            366 non-null    float64
#  9   precipprob        366 non-null    int64
#  10  precipcover       366 non-null    float64
#  11  snow              366 non-null    int64
#  12  snowdepth         366 non-null    int64
#  13  windgust          366 non-null    float64
#  14  windspeed         366 non-null    float64
#  15  winddir           366 non-null    float64
#  16  sealevelpressure  366 non-null    float64
#  17  cloudcover        366 non-null    float64
#  18  visibility        366 non-null    float64
#  19  solarradiation    366 non-null    float64
#  20  solarenergy       366 non-null    float64
#  21  uvindex           366 non-null    int64
#  22  severerisk        366 non-null    int64
#  23  sunset            366 non-null    object
#  24  moonphase         366 non-null    float64
#  25  conditions        366 non-null    object
#  26  description       366 non-null    object
#  27  icon              366 non-null    object
#  28  stations          366 non-null    object
#  29  Year              366 non-null    int32
#  30  Day               366 non-null    int32
#  31  Month             366 non-null    int32
#  32  hour_rise         366 non-null    int32
#  33  minute_rise       366 non-null    int32
#  34  second_rise       366 non-null    int32
# dtypes: float64(19), int32(6), int64(5), object(5)
# memory usage: 91.6+ KB
# None

# %%
df['sunset'] = pd.to_datetime(df['sunset'])

# Criando colunas para dia, mês, ano, hora de o sol se levantar, minuto de o sol se levantar, segundo de o sol se levantar
df['hour_set']   = df['sunset'].dt.hour
df['minute_set'] = df['sunset'].dt.minute
df['second_set'] = df['sunset'].dt.second

df.drop(['sunset'], inplace = True, axis = 1) # apaga-mos a coluna 'sunset' pois já temos essa informação

print (df.info()) #verificarmos que o sunset foi eliminado
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 37 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   tempmax           366 non-null    float64
#  1   tempmin           366 non-null    float64
#  2   temp              366 non-null    float64
#  3   feelslikemax      366 non-null    float64
#  4   feelslikemin      366 non-null    float64
#  5   feelslike         366 non-null    float64
#  6   dew               366 non-null    float64
#  7   humidity          366 non-null    float64
#  8   precip            366 non-null    float64
#  9   precipprob        366 non-null    int64
#  10  precipcover       366 non-null    float64
#  11  snow              366 non-null    int64
#  12  snowdepth         366 non-null    int64
#  13  windgust          366 non-null    float64
#  14  windspeed         366 non-null    float64
#  15  winddir           366 non-null    float64
#  16  sealevelpressure  366 non-null    float64
#  17  cloudcover        366 non-null    float64
#  18  visibility        366 non-null    float64
#  19  solarradiation    366 non-null    float64
#  20  solarenergy       366 non-null    float64
#  21  uvindex           366 non-null    int64
#  22  severerisk        366 non-null    int64
#  23  moonphase         366 non-null    float64
#  24  conditions        366 non-null    object
#  25  description       366 non-null    object
#  26  icon              366 non-null    object
#  27  stations          366 non-null    object
#  28  Year              366 non-null    int32
#  29  Day               366 non-null    int32
#  30  Month             366 non-null    int32
#  31  hour_rise         366 non-null    int32
#  32  minute_rise       366 non-null    int32
#  33  second_rise       366 non-null    int32
#  34  hour_set          366 non-null    int32
#  35  minute_set        366 non-null    int32
#  36  second_set        366 non-null    int32
# dtypes: float64(19), int32(9), int64(5), object(4)
# memory usage: 93.1+ KB
# None

# %%
df.head()
# Out:
#    tempmax  tempmin  temp  feelslikemax  feelslikemin  feelslike   dew  \
# 0     30.4     19.9  25.6          30.6          19.9       25.7  15.6
# 1     31.0     17.7  22.6          31.4          17.7       22.7  16.9
# 2     28.0     19.0  22.3          28.6          19.0       22.4  16.9
# 3     25.3     19.2  21.1          25.3          19.2       21.1  17.1
# 4     26.8     18.6  21.3          27.4          18.6       21.4  17.0
#
#    humidity  precip  precipprob  ...  \
# 0      55.1     0.0           0  ...
# 1      71.9     0.0           0  ...
# 2      72.7     0.0           0  ...
# 3      78.5     0.0           0  ...
# 4      77.7     0.0           0  ...
#
#                                             stations  Year  Day  Month  \
# 0  08535099999,08532099999,08534099999,D7126,0853...  2022    1      8
# 1  08535099999,08532099999,08534099999,D7126,0853...  2022    2      8
# 2  08535099999,08532099999,08534099999,D7126,0853...  2022    3      8
# 3  08535099999,08532099999,08534099999,D7126,0853...  2022    4      8
# 4  08535099999,08532099999,08534099999,D7126,0853...  2022    5      8
#
#    hour_rise  minute_rise  second_rise  hour_set  minute_set  second_set
# 0          6           37           52        20          47          33
# 1          6           38           44        20          46          32
# 2          6           39           37        20          45          29
# 3          6           40           30        20          44          25
# 4          6           41           23        20          43          20
#
# [5 rows x 37 columns]

# %% [markdown]
# Vamos tratar dos restantes atributos object:
#
# conditions,
# description,
# icon,
# stations,

# %% [markdown]
# Provavelmente vamos juntar as colunas conditions e description e fazer 6 novas colunas rain_morning, rain_afternoon, cloud_moring, cloud_afternoon,clear_moring, clear_afternoon

# %%
# analise do atributo conditions e transformação nele em números
print ( df['conditions'].describe() )
print('\n')
print ( df['conditions'].value_counts() )
print('\n')
print(df['conditions'])
# Out:
# count                  366
# unique                   5
# top       Partially cloudy
# freq                   192
# Name: conditions, dtype: object
#
#
# conditions
# Partially cloudy          192
# Rain, Partially cloudy    104
# Clear                      65
# Rain, Overcast              3
# Rain                        2
# Name: count, dtype: int64
#
#
# 0                       Clear
# 1            Partially cloudy
# 2            Partially cloudy
# 3            Partially cloudy
# 4            Partially cloudy
#                 ...
# 361          Partially cloudy
# 362          Partially cloudy
# 363          Partially cloudy
# 364          Partially cloudy
# 365    Rain, Partially cloudy
# Name: conditions, Length: 366, dtype: object

# %%
# analise do atributo conditions
print ( df['description'].describe() )
print('\n')
print ( df['description'].value_counts() )
print('\n')
print(df['description'])
# Out:
# count                                   366
# unique                                   19
# top       Partly cloudy throughout the day.
# freq                                    161
# Name: description, dtype: object
#
#
# description
# Partly cloudy throughout the day.                                             161
# Clear conditions throughout the day.                                           65
# Partly cloudy throughout the day with morning rain.                            56
# Clearing in the afternoon.                                                     23
# Partly cloudy throughout the day with rain in the morning and afternoon.       19
# Partly cloudy throughout the day with afternoon rain.                          13
# Becoming cloudy in the afternoon.                                               8
# Partly cloudy throughout the day with a chance of rain throughout the day.      4
# Becoming cloudy in the afternoon with morning rain.                             3
# Cloudy skies throughout the day with morning rain.                              2
# Clearing in the afternoon with morning rain.                                    2
# Clear conditions throughout the day with morning rain.                          2
# Partly cloudy throughout the day with late afternoon rain.                      2
# Partly cloudy throughout the day with rain clearing later.                      1
# Becoming cloudy in the afternoon with rain in the morning and afternoon.        1
# Cloudy skies throughout the day with afternoon rain.                            1
# Partly cloudy throughout the day with rain.                                     1
# Clearing in the afternoon with early morning rain.                              1
# Clearing in the afternoon with afternoon rain.                                  1
# Name: count, dtype: int64
#
#
# 0                   Clear conditions throughout the day.
# 1                             Clearing in the afternoon.
# 2                             Clearing in the afternoon.
# 3                      Partly cloudy throughout the day.
# 4                      Partly cloudy throughout the day.
#                              ...
# 361                           Clearing in the afternoon.
# 362                    Partly cloudy throughout the day.
# 363                    Partly cloudy throughout the day.
# 364                    Partly cloudy throughout the day.
# 365    Partly cloudy throughout the day with morning ...
# Name: description, Length: 366, dtype: object

# %%
# analise do atributo ico

print ( df['icon'].describe() )
print('\n')
print ( df['icon'].value_counts() )
print('\n')
print(df['icon'])
# Out:
# count                   366
# unique                    3
# top       partly-cloudy-day
# freq                    192
# Name: icon, dtype: object
#
#
# icon
# partly-cloudy-day    192
# rain                 109
# clear-day             65
# Name: count, dtype: int64
#
#
# 0              clear-day
# 1      partly-cloudy-day
# 2      partly-cloudy-day
# 3      partly-cloudy-day
# 4      partly-cloudy-day
#              ...
# 361    partly-cloudy-day
# 362    partly-cloudy-day
# 363    partly-cloudy-day
# 364    partly-cloudy-day
# 365                 rain
# Name: icon, Length: 366, dtype: object

# %%
# Realize o groupby 
iguais = ['conditions','description', 'icon']
df_novo = df[iguais]
print(df_novo.head())
# Out:
#          conditions                           description               icon
# 0             Clear  Clear conditions throughout the day.          clear-day
# 1  Partially cloudy            Clearing in the afternoon.  partly-cloudy-day
# 2  Partially cloudy            Clearing in the afternoon.  partly-cloudy-day
# 3  Partially cloudy     Partly cloudy throughout the day.  partly-cloudy-day
# 4  Partially cloudy     Partly cloudy throughout the day.  partly-cloudy-day

# %%
# Calcular a contagem de todas as combinações de categorias de cada coluna
contagem_combinacoes = df.groupby(['conditions', 'description', 'icon']).size().reset_index(name='count')

# exibir um dataset com a contagem da intercessão das diferentes combinações de categorias
print(contagem_combinacoes)
# Out:
#                 conditions                                        description  \
# 0                    Clear               Clear conditions throughout the day.
# 1         Partially cloudy                  Becoming cloudy in the afternoon.
# 2         Partially cloudy                         Clearing in the afternoon.
# 3         Partially cloudy                  Partly cloudy throughout the day.
# 4                     Rain  Clear conditions throughout the day with morni...
# 5           Rain, Overcast  Cloudy skies throughout the day with afternoon...
# 6           Rain, Overcast  Cloudy skies throughout the day with morning r...
# 7   Rain, Partially cloudy  Becoming cloudy in the afternoon with morning ...
# 8   Rain, Partially cloudy  Becoming cloudy in the afternoon with rain in ...
# 9   Rain, Partially cloudy     Clearing in the afternoon with afternoon rain.
# 10  Rain, Partially cloudy  Clearing in the afternoon with early morning r...
# 11  Rain, Partially cloudy       Clearing in the afternoon with morning rain.
# 12  Rain, Partially cloudy  Partly cloudy throughout the day with a chance...
# 13  Rain, Partially cloudy  Partly cloudy throughout the day with afternoo...
# 14  Rain, Partially cloudy  Partly cloudy throughout the day with late aft...
# 15  Rain, Partially cloudy  Partly cloudy throughout the day with morning ...
# 16  Rain, Partially cloudy  Partly cloudy throughout the day with rain cle...
# 17  Rain, Partially cloudy  Partly cloudy throughout the day with rain in ...
# 18  Rain, Partially cloudy        Partly cloudy throughout the day with rain.
#
#                  icon  count
# 0           clear-day     65
# 1   partly-cloudy-day      8
# 2   partly-cloudy-day     23
# 3   partly-cloudy-day    161
# 4                rain      2
# 5                rain      1
# 6                rain      2
# 7                rain      3
# 8                rain      1
# 9                rain      1
# 10               rain      1
# 11               rain      2
# 12               rain      4
# 13               rain     13
# 14               rain      2
# 15               rain     56
# 16               rain      1
# 17               rain     19
# 18               rain      1

# %% [markdown]
# Criar os atributos binários a partir da coluna descrição (temdo em conta o dataset triplo anterior)

# %%
# Criar os atributos binários
df['rain_morning'] = (df['description'].str.contains('Clearing in the afternoon with morning rain.') |
                      df['description'].str.contains('Clearing in the afternoon with early morning rain.') |
                      df['description'].str.contains('Partly cloudy throughout the day with morning rain.') |
                      df['description'].str.contains('Partly cloudy throughout the day with rain in the morning and afternoon.') |
                      df['description'].str.contains('Partly cloudy throughout the day with a chance of rain throughout the day.') |
                      df['description'].str.contains('Becoming cloudy in the afternoon with morning rain.') |
                      df['description'].str.contains('Cloudy skies throughout the day with morning rain.') |
                      df['description'].str.contains('Clear conditions throughout the day with morning rain.') |
                      df['description'].str.contains('Partly cloudy throughout the day with rain clearing later.') |
                      df['description'].str.contains('Becoming cloudy in the afternoon with rain in the morning and afternoon.') |
                      df['description'].str.contains('Partly cloudy throughout the day with rain.')).astype(int)

# %%
df['rain_afternoon'] = (df['description'].str.contains('Clearing in the afternoon with afternoon rain.') |
                        df['description'].str.contains('Partly cloudy throughout the day with rain in the morning and afternoon.') |
                        df['description'].str.contains('Partly cloudy throughout the day with afternoon rain.')
                        # Adicione mais condições aqui conforme necessário
                       ).astype(int)

# %%
df['cloud_morning'] = (df['description'].str.contains('Clearing in the afternoon.') |
                       df['description'].str.contains('Partly cloudy throughout the day.') |
                       df['description'].str.contains('Partly cloudy throughout the day with afternoon rain.') |
                       df['description'].str.contains('Partly cloudy throughout the day with late afternoon rain.') |
                       df['description'].str.contains('Cloudy skies throughout the day with afternoon rain.')
                      ).astype(int)

# %%
df['cloud_afternoon'] = (df['description'].str.contains('Partly cloudy throughout the day.') |
                         df['description'].str.contains('Partly cloudy throughout the day with morning rain.') |
                         df['description'].str.contains('Becoming cloudy in the afternoon.') |
                         df['description'].str.contains('Becoming cloudy in the afternoon with morning rain.') |
                         df['description'].str.contains('Cloudy skies throughout the day with morning rain.')
                        ).astype(int)

# %%
df['clear_morning'] = (df['description'].str.contains('Clear conditions throughout the day.') |
                      df['description'].str.contains('Becoming cloudy in the afternoon.')
                     ).astype(int)

# %%
df['clear_afternoon'] = (df['description'].str.contains('Clear conditions throughout the day.') |
                        df['description'].str.contains('Clearing in the afternoon.') |
                        df['description'].str.contains('Clearing in the afternoon with morning rain.') |
                        df['description'].str.contains('Clearing in the afternoon with early morning rain.') |
                        df['description'].str.contains('Clearing in the afternoon with afternoon rain.') |
                        df['description'].str.contains('Clear conditions throughout the day with morning rain.') |
                        df['description'].str.contains('Partly cloudy throughout the day with rain clearing later.')
                       ).astype(int)


df.drop(['description'], inplace = True, axis = 1)
df.drop(['conditions'], inplace = True, axis = 1)
df.drop(['icon'], inplace = True, axis = 1)
print ( df.info() )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 40 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   tempmax           366 non-null    float64
#  1   tempmin           366 non-null    float64
#  2   temp              366 non-null    float64
#  3   feelslikemax      366 non-null    float64
#  4   feelslikemin      366 non-null    float64
#  5   feelslike         366 non-null    float64
#  6   dew               366 non-null    float64
#  7   humidity          366 non-null    float64
#  8   precip            366 non-null    float64
#  9   precipprob        366 non-null    int64
#  10  precipcover       366 non-null    float64
#  11  snow              366 non-null    int64
#  12  snowdepth         366 non-null    int64
#  13  windgust          366 non-null    float64
#  14  windspeed         366 non-null    float64
#  15  winddir           366 non-null    float64
#  16  sealevelpressure  366 non-null    float64
#  17  cloudcover        366 non-null    float64
#  18  visibility        366 non-null    float64
#  19  solarradiation    366 non-null    float64
#  20  solarenergy       366 non-null    float64
#  21  uvindex           366 non-null    int64
#  22  severerisk        366 non-null    int64
#  23  moonphase         366 non-null    float64
#  24  stations          366 non-null    object
#  25  Year              366 non-null    int32
#  26  Day               366 non-null    int32
#  27  Month             366 non-null    int32
#  28  hour_rise         366 non-null    int32
#  29  minute_rise       366 non-null    int32
#  30  second_rise       366 non-null    int32
#  31  hour_set          366 non-null    int32
#  32  minute_set        366 non-null    int32
#  33  second_set        366 non-null    int32
#  34  rain_morning      366 non-null    int32
#  35  rain_afternoon    366 non-null    int32
#  36  cloud_morning     366 non-null    int32
#  37  cloud_afternoon   366 non-null    int32
#  38  clear_morning     366 non-null    int32
#  39  clear_afternoon   366 non-null    int32
# dtypes: float64(19), int32(15), int64(5), object(1)
# memory usage: 93.1+ KB
# None

# %%
# analise do atributo precip

print ( df['precip'].describe() )
print('\n')
print ( df['precip'].value_counts() )
print('\n')
print(df['precip'])

# conlcusão é util
# Out:
# count    366.000000
# mean       1.358077
# std        5.396396
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.095000
# max       60.570000
# Name: precip, dtype: float64
#
#
# precip
# 0.000    257
# 0.100      9
# 0.001      4
# 0.080      3
# 9.000      3
#         ...
# 4.300      1
# 0.761      1
# 1.325      1
# 5.393      1
# 0.970      1
# Name: count, Length: 86, dtype: int64
#
#
# 0      0.00
# 1      0.00
# 2      0.00
# 3      0.00
# 4      0.00
#        ...
# 361    0.00
# 362    0.00
# 363    0.00
# 364    0.00
# 365    0.02
# Name: precip, Length: 366, dtype: float64

# %%
# analise do atributo precipprob
print ( df['precipprob'].describe() )
print('\n')
print ( df['precipprob'].value_counts() )
print('\n')
print(df['precipprob'])
# vemos que é um atributo que é ou 0 ou 100, para dizer se chove ou não logo como já temos as 
#colunas rain_morning and rain_afternoon concluimos que ele é inutil
# Out:
# count    366.000000
# mean      29.781421
# std       45.792340
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%      100.000000
# max      100.000000
# Name: precipprob, dtype: float64
#
#
# precipprob
# 0      257
# 100    109
# Name: count, dtype: int64
#
#
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#       ...
# 361      0
# 362      0
# 363      0
# 364      0
# 365    100
# Name: precipprob, Length: 366, dtype: int64

# %%
df.drop(['precipprob'], inplace = True, axis = 1) # apagar a coluna inutil

# %%
# analise do atributo precipcover
print ( df['precipcover'].describe() )
print('\n')
print ( df['precipcover'].value_counts() )
print('\n')
print(df['precipcover'])
# é util deve ficar
# Out:
# count    366.000000
# mean       1.890355
# std        5.372178
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        4.170000
# max       79.170000
# Name: precipcover, dtype: float64
#
#
# precipcover
# 0.00     257
# 4.17      83
# 8.33      22
# 20.83      2
# 79.17      1
# 41.67      1
# Name: count, dtype: int64
#
#
# 0      0.00
# 1      0.00
# 2      0.00
# 3      0.00
# 4      0.00
#        ...
# 361    0.00
# 362    0.00
# 363    0.00
# 364    0.00
# 365    4.17
# Name: precipcover, Length: 366, dtype: float64

# %%
df.nunique()
# Out:
# tempmax             145
# tempmin             131
# temp                152
# feelslikemax        141
# feelslikemin        140
# feelslike           157
# dew                 145
# humidity            260
# precip               86
# precipcover           6
# snow                  1
# snowdepth             1
# windgust            103
# windspeed           178
# winddir             338
# sealevelpressure    181
# cloudcover          295
# visibility           48
# solarradiation      346
# solarenergy         206
# uvindex              11
# severerisk            2
# moonphase            93
# stations              6
# Year                  2
# Day                  31
# Month                12
# hour_rise             3
# minute_rise          60
# second_rise          60
# hour_set              5
# minute_set           60
# second_set           60
# rain_morning          2
# rain_afternoon        2
# cloud_morning         2
# cloud_afternoon       2
# clear_morning         2
# clear_afternoon       2
# dtype: int64

# %% [markdown]
# Temos de alterar as colunas que têm muitos valores unicos, depois falar com o pessoal para dicutir qual deve ser o numero aceitavel de valores unicos.

# %% [markdown]
# Neste momento as colunas que têm de ser reconfiguradas são: winddir,solarradiation ,solarenergy, cloudcover e humidity.

# %%
# analise do atributo precipcover
print ( df['winddir'].describe() )
print('\n')
print ( df['winddir'].value_counts() )
print('\n')
print(df['winddir'].nunique())
print('\n')
print(df['winddir'])
# acho que temos demasiados valores diferentes de 366 entradas 338 são diferentes talvez tenhamos de criar classes talvez
#baseadas nos quatis ou algo do genero, mas por enquanto deve ficar
# Out:
# count    366.000000
# mean     244.606831
# std      110.121673
# min        0.800000
# 25%      209.875000
# 50%      279.100000
# 75%      331.450000
# max      359.900000
# Name: winddir, dtype: float64
#
#
# winddir
# 323.4    2
# 349.0    2
# 33.9     2
# 330.9    2
# 334.2    2
#         ..
# 350.6    1
# 41.6     1
# 7.9      1
# 229.3    1
# 340.0    1
# Name: count, Length: 338, dtype: int64
#
#
# 338
#
#
# 0      252.6
# 1      269.5
# 2      335.5
# 3      338.9
# 4      310.1
#        ...
# 361    327.9
# 362    321.6
# 363    334.2
# 364    331.3
# 365    340.0
# Name: winddir, Length: 366, dtype: float64

# %%
# analise do atributo stations

print ( df['stations'].describe() )
print('\n')
print ( df['stations'].value_counts() )
print('\n')
print(df['stations'])

# Criar uma lista única de todas as estações
all_stations = set(','.join(df['stations']).split(','))

# Criar colunas binárias para cada estação
for station in all_stations:
    df[station] = df['stations'].apply(lambda x: int(station in x))

# Remover a coluna original 'stations'
df = df.drop('stations', axis=1)

print('\n')
df.info()
# Out:
# count                                                366
# unique                                                 6
# top       08532099999,08534099999,D7126,08536099999,LPPT
# freq                                                 151
# Name: stations, dtype: object
#
#
# stations
# 08532099999,08534099999,D7126,08536099999,LPPT                151
# 08535099999,08532099999,08534099999,D7126,08536099999,LPPT     78
# 08534099999,D7126,08536099999,LPPT                             71
# 08535099999,08534099999,D7126,08536099999,LPPT                 29
# 08532099999,08534099999,08536099999,LPPT                       25
# 08534099999,08536099999,LPPT                                   12
# Name: count, dtype: int64
#
#
# 0      08535099999,08532099999,08534099999,D7126,0853...
# 1      08535099999,08532099999,08534099999,D7126,0853...
# 2      08535099999,08532099999,08534099999,D7126,0853...
# 3      08535099999,08532099999,08534099999,D7126,0853...
# 4      08535099999,08532099999,08534099999,D7126,0853...
#                              ...
# 361             08532099999,08534099999,08536099999,LPPT
# 362                         08534099999,08536099999,LPPT
# 363                         08534099999,08536099999,LPPT
# 364       08532099999,08534099999,D7126,08536099999,LPPT
# 365       08532099999,08534099999,D7126,08536099999,LPPT
# Name: stations, Length: 366, dtype: object
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 44 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   tempmax           366 non-null    float64
#  1   tempmin           366 non-null    float64
#  2   temp              366 non-null    float64
#  3   feelslikemax      366 non-null    float64
#  4   feelslikemin      366 non-null    float64
#  5   feelslike         366 non-null    float64
#  6   dew               366 non-null    float64
#  7   humidity          366 non-null    float64
#  8   precip            366 non-null    float64
#  9   precipcover       366 non-null    float64
#  10  snow              366 non-null    int64
#  11  snowdepth         366 non-null    int64
#  12  windgust          366 non-null    float64
#  13  windspeed         366 non-null    float64
#  14  winddir           366 non-null    float64
#  15  sealevelpressure  366 non-null    float64
#  16  cloudcover        366 non-null    float64
#  17  visibility        366 non-null    float64
#  18  solarradiation    366 non-null    float64
#  19  solarenergy       366 non-null    float64
#  20  uvindex           366 non-null    int64
#  21  severerisk        366 non-null    int64
#  22  moonphase         366 non-null    float64
#  23  Year              366 non-null    int32
#  24  Day               366 non-null    int32
#  25  Month             366 non-null    int32
#  26  hour_rise         366 non-null    int32
#  27  minute_rise       366 non-null    int32
#  28  second_rise       366 non-null    int32
#  29  hour_set          366 non-null    int32
#  30  minute_set        366 non-null    int32
#  31  second_set        366 non-null    int32
#  32  rain_morning      366 non-null    int32
#  33  rain_afternoon    366 non-null    int32
#  34  cloud_morning     366 non-null    int32
#  35  cloud_afternoon   366 non-null    int32
#  36  clear_morning     366 non-null    int32
#  37  clear_afternoon   366 non-null    int32
#  38  08535099999       366 non-null    int64
#  39  08532099999       366 non-null    int64
#  40  08534099999       366 non-null    int64
#  41  08536099999       366 non-null    int64
#  42  D7126             366 non-null    int64
#  43  LPPT              366 non-null    int64
# dtypes: float64(19), int32(15), int64(10)
# memory usage: 104.5 KB

# %%
df.nunique()
# Out:
# tempmax             145
# tempmin             131
# temp                152
# feelslikemax        141
# feelslikemin        140
# feelslike           157
# dew                 145
# humidity            260
# precip               86
# precipcover           6
# snow                  1
# snowdepth             1
# windgust            103
# windspeed           178
# winddir             338
# sealevelpressure    181
# cloudcover          295
# visibility           48
# solarradiation      346
# solarenergy         206
# uvindex              11
# severerisk            2
# moonphase            93
# Year                  2
# Day                  31
# Month                12
# hour_rise             3
# minute_rise          60
# second_rise          60
# hour_set              5
# minute_set           60
# second_set           60
# rain_morning          2
# rain_afternoon        2
# cloud_morning         2
# cloud_afternoon       2
# clear_morning         2
# clear_afternoon       2
# 08535099999           2
# 08532099999           2
# 08534099999           1
# 08536099999           1
# D7126                 2
# LPPT                  1
# dtype: int64

# %%
#alalise do atributo severerisk
print ( df['severerisk'].describe() )
print('\n')
print ( df['severerisk'].value_counts() )
# Out:
# count    366.000000
# mean      10.273224
# std        2.324779
# min       10.000000
# 25%       10.000000
# 50%       10.000000
# 75%       10.000000
# max       30.000000
# Name: severerisk, dtype: float64
#
#
# severerisk
# 10    361
# 30      5
# Name: count, dtype: int64

# %%
# Nunca nevou logo esta coluna é unutil
print ( df['snow'].describe() )
print('\n')
print ( df['snow'].value_counts() )
df.drop(['snow'], inplace = True, axis = 1)
df.info()
# Out:
# count    366.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# Name: snow, dtype: float64
#
#
# snow
# 0    366
# Name: count, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 43 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   tempmax           366 non-null    float64
#  1   tempmin           366 non-null    float64
#  2   temp              366 non-null    float64
#  3   feelslikemax      366 non-null    float64
#  4   feelslikemin      366 non-null    float64
#  5   feelslike         366 non-null    float64
#  6   dew               366 non-null    float64
#  7   humidity          366 non-null    float64
#  8   precip            366 non-null    float64
#  9   precipcover       366 non-null    float64
#  10  snowdepth         366 non-null    int64
#  11  windgust          366 non-null    float64
#  12  windspeed         366 non-null    float64
#  13  winddir           366 non-null    float64
#  14  sealevelpressure  366 non-null    float64
#  15  cloudcover        366 non-null    float64
#  16  visibility        366 non-null    float64
#  17  solarradiation    366 non-null    float64
#  18  solarenergy       366 non-null    float64
#  19  uvindex           366 non-null    int64
#  20  severerisk        366 non-null    int64
#  21  moonphase         366 non-null    float64
#  22  Year              366 non-null    int32
#  23  Day               366 non-null    int32
#  24  Month             366 non-null    int32
#  25  hour_rise         366 non-null    int32
#  26  minute_rise       366 non-null    int32
#  27  second_rise       366 non-null    int32
#  28  hour_set          366 non-null    int32
#  29  minute_set        366 non-null    int32
#  30  second_set        366 non-null    int32
#  31  rain_morning      366 non-null    int32
#  32  rain_afternoon    366 non-null    int32
#  33  cloud_morning     366 non-null    int32
#  34  cloud_afternoon   366 non-null    int32
#  35  clear_morning     366 non-null    int32
#  36  clear_afternoon   366 non-null    int32
#  37  08535099999       366 non-null    int64
#  38  08532099999       366 non-null    int64
#  39  08534099999       366 non-null    int64
#  40  08536099999       366 non-null    int64
#  41  D7126             366 non-null    int64
#  42  LPPT              366 non-null    int64
# dtypes: float64(19), int32(15), int64(9)
# memory usage: 101.6 KB

# %%
# Nunca nevou logo esta coluna é unutil
print ( df['snowdepth'].describe() )
print('\n')
print ( df['snowdepth'].value_counts() )
df.drop(['snowdepth'], inplace = True, axis = 1)
df.info()
# Out:
# count    366.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# Name: snowdepth, dtype: float64
#
#
# snowdepth
# 0    366
# Name: count, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 42 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   tempmax           366 non-null    float64
#  1   tempmin           366 non-null    float64
#  2   temp              366 non-null    float64
#  3   feelslikemax      366 non-null    float64
#  4   feelslikemin      366 non-null    float64
#  5   feelslike         366 non-null    float64
#  6   dew               366 non-null    float64
#  7   humidity          366 non-null    float64
#  8   precip            366 non-null    float64
#  9   precipcover       366 non-null    float64
#  10  windgust          366 non-null    float64
#  11  windspeed         366 non-null    float64
#  12  winddir           366 non-null    float64
#  13  sealevelpressure  366 non-null    float64
#  14  cloudcover        366 non-null    float64
#  15  visibility        366 non-null    float64
#  16  solarradiation    366 non-null    float64
#  17  solarenergy       366 non-null    float64
#  18  uvindex           366 non-null    int64
#  19  severerisk        366 non-null    int64
#  20  moonphase         366 non-null    float64
#  21  Year              366 non-null    int32
#  22  Day               366 non-null    int32
#  23  Month             366 non-null    int32
#  24  hour_rise         366 non-null    int32
#  25  minute_rise       366 non-null    int32
#  26  second_rise       366 non-null    int32
#  27  hour_set          366 non-null    int32
#  28  minute_set        366 non-null    int32
#  29  second_set        366 non-null    int32
#  30  rain_morning      366 non-null    int32
#  31  rain_afternoon    366 non-null    int32
#  32  cloud_morning     366 non-null    int32
#  33  cloud_afternoon   366 non-null    int32
#  34  clear_morning     366 non-null    int32
#  35  clear_afternoon   366 non-null    int32
#  36  08535099999       366 non-null    int64
#  37  08532099999       366 non-null    int64
#  38  08534099999       366 non-null    int64
#  39  08536099999       366 non-null    int64
#  40  D7126             366 non-null    int64
#  41  LPPT              366 non-null    int64
# dtypes: float64(19), int32(15), int64(8)
# memory usage: 98.8 KB

# %%
# Esta estação reguistou sempre os dados meteriológicos de todos os dias loga esta coluna é unutil 
print ( df['08534099999'].describe() )
print('\n')
print ( df['08534099999'].value_counts() )
df.drop(['08534099999'], inplace = True, axis = 1)
df.info()
# Out:
# count    366.0
# mean       1.0
# std        0.0
# min        1.0
# 25%        1.0
# 50%        1.0
# 75%        1.0
# max        1.0
# Name: 08534099999, dtype: float64
#
#
# 08534099999
# 1    366
# Name: count, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 41 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   tempmax           366 non-null    float64
#  1   tempmin           366 non-null    float64
#  2   temp              366 non-null    float64
#  3   feelslikemax      366 non-null    float64
#  4   feelslikemin      366 non-null    float64
#  5   feelslike         366 non-null    float64
#  6   dew               366 non-null    float64
#  7   humidity          366 non-null    float64
#  8   precip            366 non-null    float64
#  9   precipcover       366 non-null    float64
#  10  windgust          366 non-null    float64
#  11  windspeed         366 non-null    float64
#  12  winddir           366 non-null    float64
#  13  sealevelpressure  366 non-null    float64
#  14  cloudcover        366 non-null    float64
#  15  visibility        366 non-null    float64
#  16  solarradiation    366 non-null    float64
#  17  solarenergy       366 non-null    float64
#  18  uvindex           366 non-null    int64
#  19  severerisk        366 non-null    int64
#  20  moonphase         366 non-null    float64
#  21  Year              366 non-null    int32
#  22  Day               366 non-null    int32
#  23  Month             366 non-null    int32
#  24  hour_rise         366 non-null    int32
#  25  minute_rise       366 non-null    int32
#  26  second_rise       366 non-null    int32
#  27  hour_set          366 non-null    int32
#  28  minute_set        366 non-null    int32
#  29  second_set        366 non-null    int32
#  30  rain_morning      366 non-null    int32
#  31  rain_afternoon    366 non-null    int32
#  32  cloud_morning     366 non-null    int32
#  33  cloud_afternoon   366 non-null    int32
#  34  clear_morning     366 non-null    int32
#  35  clear_afternoon   366 non-null    int32
#  36  08535099999       366 non-null    int64
#  37  08532099999       366 non-null    int64
#  38  08536099999       366 non-null    int64
#  39  D7126             366 non-null    int64
#  40  LPPT              366 non-null    int64
# dtypes: float64(19), int32(15), int64(7)
# memory usage: 95.9 KB

# %%
# Esta estação reguistou sempre os dados meteriológicos de todos os dias loga esta coluna é unutil 
print ( df['08536099999'].describe() )
print('\n')
print ( df['08536099999'].value_counts() )
df.drop(['08536099999'], inplace = True, axis = 1)
df.info()
# Out:
# count    366.0
# mean       1.0
# std        0.0
# min        1.0
# 25%        1.0
# 50%        1.0
# 75%        1.0
# max        1.0
# Name: 08536099999, dtype: float64
#
#
# 08536099999
# 1    366
# Name: count, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 40 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   tempmax           366 non-null    float64
#  1   tempmin           366 non-null    float64
#  2   temp              366 non-null    float64
#  3   feelslikemax      366 non-null    float64
#  4   feelslikemin      366 non-null    float64
#  5   feelslike         366 non-null    float64
#  6   dew               366 non-null    float64
#  7   humidity          366 non-null    float64
#  8   precip            366 non-null    float64
#  9   precipcover       366 non-null    float64
#  10  windgust          366 non-null    float64
#  11  windspeed         366 non-null    float64
#  12  winddir           366 non-null    float64
#  13  sealevelpressure  366 non-null    float64
#  14  cloudcover        366 non-null    float64
#  15  visibility        366 non-null    float64
#  16  solarradiation    366 non-null    float64
#  17  solarenergy       366 non-null    float64
#  18  uvindex           366 non-null    int64
#  19  severerisk        366 non-null    int64
#  20  moonphase         366 non-null    float64
#  21  Year              366 non-null    int32
#  22  Day               366 non-null    int32
#  23  Month             366 non-null    int32
#  24  hour_rise         366 non-null    int32
#  25  minute_rise       366 non-null    int32
#  26  second_rise       366 non-null    int32
#  27  hour_set          366 non-null    int32
#  28  minute_set        366 non-null    int32
#  29  second_set        366 non-null    int32
#  30  rain_morning      366 non-null    int32
#  31  rain_afternoon    366 non-null    int32
#  32  cloud_morning     366 non-null    int32
#  33  cloud_afternoon   366 non-null    int32
#  34  clear_morning     366 non-null    int32
#  35  clear_afternoon   366 non-null    int32
#  36  08535099999       366 non-null    int64
#  37  08532099999       366 non-null    int64
#  38  D7126             366 non-null    int64
#  39  LPPT              366 non-null    int64
# dtypes: float64(19), int32(15), int64(6)
# memory usage: 93.1 KB

# %%
# Esta estação reguistou sempre os dados meteriológicos de todos os dias loga esta coluna é unutil 
print ( df['LPPT'].describe() )
print('\n')
print ( df['LPPT'].value_counts() )
df.drop(['LPPT'], inplace = True, axis = 1)
df.info()
# Out:
# count    366.0
# mean       1.0
# std        0.0
# min        1.0
# 25%        1.0
# 50%        1.0
# 75%        1.0
# max        1.0
# Name: LPPT, dtype: float64
#
#
# LPPT
# 1    366
# Name: count, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 39 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   tempmax           366 non-null    float64
#  1   tempmin           366 non-null    float64
#  2   temp              366 non-null    float64
#  3   feelslikemax      366 non-null    float64
#  4   feelslikemin      366 non-null    float64
#  5   feelslike         366 non-null    float64
#  6   dew               366 non-null    float64
#  7   humidity          366 non-null    float64
#  8   precip            366 non-null    float64
#  9   precipcover       366 non-null    float64
#  10  windgust          366 non-null    float64
#  11  windspeed         366 non-null    float64
#  12  winddir           366 non-null    float64
#  13  sealevelpressure  366 non-null    float64
#  14  cloudcover        366 non-null    float64
#  15  visibility        366 non-null    float64
#  16  solarradiation    366 non-null    float64
#  17  solarenergy       366 non-null    float64
#  18  uvindex           366 non-null    int64
#  19  severerisk        366 non-null    int64
#  20  moonphase         366 non-null    float64
#  21  Year              366 non-null    int32
#  22  Day               366 non-null    int32
#  23  Month             366 non-null    int32
#  24  hour_rise         366 non-null    int32
#  25  minute_rise       366 non-null    int32
#  26  second_rise       366 non-null    int32
#  27  hour_set          366 non-null    int32
#  28  minute_set        366 non-null    int32
#  29  second_set        366 non-null    int32
#  30  rain_morning      366 non-null    int32
#  31  rain_afternoon    366 non-null    int32
#  32  cloud_morning     366 non-null    int32
#  33  cloud_afternoon   366 non-null    int32
#  34  clear_morning     366 non-null    int32
#  35  clear_afternoon   366 non-null    int32
#  36  08535099999       366 non-null    int64
#  37  08532099999       366 non-null    int64
#  38  D7126             366 non-null    int64
# dtypes: float64(19), int32(15), int64(5)
# memory usage: 90.2 KB

# %%
corr_matrix = df.corr()
f,ax =  plt.subplots(figsize = (40,40))
sns.heatmap(corr_matrix, vmin=-1, vmax=1, annot=True, square=True)
# Out:
# <Axes: >
